# %% [markdown]
# <a href="https://colab.research.google.com/github/vincentp3/supersigma/blob/main/sigmadb_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Base de données à partir de fichiers sigma.

# %% [markdown]
# ## Chargement des données sigma

# %%
# !wget https://github.com/SigmaHQ/sigma/archive/refs/heads/master.zip
# !unzip master.zip
# Out:
# --2021-11-25 08:24:18--  https://github.com/SigmaHQ/sigma/archive/refs/heads/master.zip
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/SigmaHQ/sigma/zip/refs/heads/master [following]
# --2021-11-25 08:24:18--  https://codeload.github.com/SigmaHQ/sigma/zip/refs/heads/master
# Resolving codeload.github.com (codeload.github.com)... 140.82.114.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.114.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [   <=>              ]   4.68M  9.34MB/s    in 0.5s
#
# 2021-11-25 08:24:19 (9.34 MB/s) - ‘master.zip’ saved [4906864]
#
# Archive:  master.zip
# 6f87ca8b549ab69ffe039339a9b4a28e9ece2137
#    creating: sigma-master/
#    creating: sigma-master/.github/
#    creating: sigma-master/.github/workflows/
#   inflating: sigma-master/.github/workflows/sigma-test.yml
#   inflating: sigma-master/.gitignore
#   inflating: sigma-master/.yamllint
#   inflating: sigma-master/BREAKING_CHANGES.md
#   inflating: sigma-master/CHANGELOG.md
#   inflating: sigma-master/CHANGELOG.md.j2
#   inflating: sigma-master/LICENSE
#   inflating: sigma-master/LICENSE.Detection.Rules.md
#   inflating: sigma-master/Makefile
#   inflating: sigma-master/Pipfile
#   inflating: sigma-master/Pipfile.lock
#   inflating: sigma-master/README.md
#   inflating: sigma-master/_config.yml
#    creating: sigma-master/contrib/
#   inflating: sigma-master/contrib/filter-uuid-patch
#   inflating: sigma-master/contrib/sigma2CSV.py
#   inflating: sigma-master/contrib/sigma2elastalert.py
#   inflating: sigma-master/contrib/sigma2sumologic.py
#   inflating: sigma-master/contrib/sigmacover.py
#    creating: sigma-master/images/
#   inflating: sigma-master/images/Problem_OSI_v01.png
#   inflating: sigma-master/images/Sigma-description.png
#   inflating: sigma-master/images/Sigma_0.3.png
#   inflating: sigma-master/images/Sigma_0.3_inverted_title_wiki.png
#   inflating: sigma-master/images/Sigma_Coverage.png
#   inflating: sigma-master/images/Sigma_Schema.png
#   inflating: sigma-master/images/Sigma_rule_example1.png
#   inflating: sigma-master/images/Sigma_rule_example2.png
#   inflating: sigma-master/images/Sigma_rule_example3.png
#   inflating: sigma-master/images/Sigma_rule_example4.png
#   inflating: sigma-master/images/Sigma_rule_example5.png
#   inflating: sigma-master/images/Sigmac-win_susp_rc4_kerberos.png
#   inflating: sigma-master/images/sigma2attack.png
#   inflating: sigma-master/images/sigma_infographic_hq.png
#   inflating: sigma-master/images/sigma_infographic_lq.png
#    creating: sigma-master/other/
#   inflating: sigma-master/other/godmode_sigma_rule.yml
#   inflating: sigma-master/other/sigma_attack_nav_coverage.json
#   inflating: sigma-master/other/sigma_attack_nav_coverage.png
#    creating: sigma-master/rules-unsupported/
#   inflating: sigma-master/rules-unsupported/driver_load_invoke_obfuscation_clip+_services.yml
#   inflating: sigma-master/rules-unsupported/driver_load_invoke_obfuscation_obfuscated_iex_services.yml
#   inflating: sigma-master/rules-unsupported/driver_load_invoke_obfuscation_stdin+_services.yml
#   inflating: sigma-master/rules-unsupported/driver_load_invoke_obfuscation_var+_services.yml
#   inflating: sigma-master/rules-unsupported/driver_load_invoke_obfuscation_via_compress_services.yml
#   inflating: sigma-master/rules-unsupported/driver_load_invoke_obfuscation_via_rundll_services.yml
#   inflating: sigma-master/rules-unsupported/driver_load_invoke_obfuscation_via_stdin_services.yml
#   inflating: sigma-master/rules-unsupported/driver_load_invoke_obfuscation_via_use_clip_services.yml
#   inflating: sigma-master/rules-unsupported/driver_load_invoke_obfuscation_via_use_mshta_services.yml
#   inflating: sigma-master/rules-unsupported/driver_load_invoke_obfuscation_via_use_rundll32_services.yml
#   inflating: sigma-master/rules-unsupported/driver_load_invoke_obfuscation_via_var++_services.yml
#   inflating: sigma-master/rules-unsupported/driver_load_tap_driver_installation.yml
#   inflating: sigma-master/rules-unsupported/file_event_executable_and_script_creation_by_office_using_file_ext.yml
#   inflating: sigma-master/rules-unsupported/lnx_auditd_omigod_scx_runasprovider_executescript.yml
#   inflating: sigma-master/rules-unsupported/net_dns_high_subdomain_rate.yml
#   inflating: sigma-master/rules-unsupported/net_dns_large_domain_name.yml
#   inflating: sigma-master/rules-unsupported/net_possible_dns_rebinding.yml
#   inflating: sigma-master/rules-unsupported/sysmon_always_install_elevated_msi_spawned_cmd_and_powershell_spawned_processes.yml
#   inflating: sigma-master/rules-unsupported/sysmon_always_install_elevated_parent_child_correlated.yml
#   inflating: sigma-master/rules-unsupported/sysmon_non_priv_program_files_move.yml
#   inflating: sigma-master/rules-unsupported/sysmon_process_reimaging.yml
#   inflating: sigma-master/rules-unsupported/win_access_fake_files_with_stored_credentials.yml
#   inflating: sigma-master/rules-unsupported/win_apt_apt29_tor.yml
#   inflating: sigma-master/rules-unsupported/win_dumping_ntdsdit_via_dcsync.yml
#   inflating: sigma-master/rules-unsupported/win_dumping_ntdsdit_via_netsync.yml
#   inflating: sigma-master/rules-unsupported/win_kernel_and_3rd_party_drivers_exploits_token_stealing.yml
#   inflating: sigma-master/rules-unsupported/win_mal_service_installs.yml
#   inflating: sigma-master/rules-unsupported/win_metasploit_or_impacket_smb_psexec_service_install.yml
#   inflating: sigma-master/rules-unsupported/win_possible_privilege_escalation_using_rotten_potato.yml
#   inflating: sigma-master/rules-unsupported/win_remote_schtask.yml
#   inflating: sigma-master/rules-unsupported/win_remote_service.yml
#   inflating: sigma-master/rules-unsupported/win_suspicious_werfault_connection_outbound.yml
#    creating: sigma-master/rules-unsupported/zeek/
#   inflating: sigma-master/rules-unsupported/zeek/zeek_http_exfiltration_compressed_files.yml
#    creating: sigma-master/rules/
#    creating: sigma-master/rules/application/
#   inflating: sigma-master/rules/application/app_python_sql_exceptions.yml
#   inflating: sigma-master/rules/application/app_sqlinjection_errors.yml
#   inflating: sigma-master/rules/application/appframework_django_exceptions.yml
#   inflating: sigma-master/rules/application/appframework_ruby_on_rails_exceptions.yml
#   inflating: sigma-master/rules/application/appframework_spring_exceptions.yml
#    creating: sigma-master/rules/apt/
#   inflating: sigma-master/rules/apt/apt_silence_downloader_v3.yml
#   inflating: sigma-master/rules/apt/apt_silence_eda.yml
#    creating: sigma-master/rules/cloud/
#    creating: sigma-master/rules/cloud/aws/
#   inflating: sigma-master/rules/cloud/aws/aws_attached_malicious_lambda_layer.yml
#   inflating: sigma-master/rules/cloud/aws/aws_cloudtrail_disable_logging.yml
#   inflating: sigma-master/rules/cloud/aws/aws_config_disable_recording.yml
#   inflating: sigma-master/rules/cloud/aws/aws_ec2_disable_encryption.yml
#   inflating: sigma-master/rules/cloud/aws/aws_ec2_download_userdata.yml
#   inflating: sigma-master/rules/cloud/aws/aws_ec2_startup_script_change.yml
#   inflating: sigma-master/rules/cloud/aws/aws_ec2_vm_export_failure.yml
#   inflating: sigma-master/rules/cloud/aws/aws_efs_fileshare_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/aws/aws_efs_fileshare_mount_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/aws/aws_eks_cluster_created_or_deleted.yml
#   inflating: sigma-master/rules/cloud/aws/aws_elasticache_security_group_created.yml
#   inflating: sigma-master/rules/cloud/aws/aws_elasticache_security_group_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/aws/aws_enum_listing.yml
#   inflating: sigma-master/rules/cloud/aws/aws_guardduty_disruption.yml
#   inflating: sigma-master/rules/cloud/aws/aws_iam_backdoor_users_keys.yml
#   inflating: sigma-master/rules/cloud/aws/aws_lambda_function_created_or_invoked.yml
#   inflating: sigma-master/rules/cloud/aws/aws_macic_evasion.yml
#   inflating: sigma-master/rules/cloud/aws/aws_passed_role_to_glue_development_endpoint.yml
#   inflating: sigma-master/rules/cloud/aws/aws_rds_change_master_password.yml
#   inflating: sigma-master/rules/cloud/aws/aws_rds_public_db_restore.yml
#   inflating: sigma-master/rules/cloud/aws/aws_root_account_usage.yml
#   inflating: sigma-master/rules/cloud/aws/aws_route_53_domain_transferred_lock_disabled.yml
#   inflating: sigma-master/rules/cloud/aws/aws_route_53_domain_transferred_to_another_account.yml
#   inflating: sigma-master/rules/cloud/aws/aws_s3_data_management_tampering.yml
#   inflating: sigma-master/rules/cloud/aws/aws_securityhub_finding_evasion.yml
#   inflating: sigma-master/rules/cloud/aws/aws_snapshot_backup_exfiltration.yml
#   inflating: sigma-master/rules/cloud/aws/aws_sts_assumerole_misuse.yml
#   inflating: sigma-master/rules/cloud/aws/aws_sts_getsessiontoken_misuse.yml
#   inflating: sigma-master/rules/cloud/aws/aws_suspicious_saml_activity.yml
#   inflating: sigma-master/rules/cloud/aws/aws_update_login_profile.yml
#    creating: sigma-master/rules/cloud/azure/
#   inflating: sigma-master/rules/cloud/azure/azure_aadhybridhealth_adfs_new_server.yml
#   inflating: sigma-master/rules/cloud/azure/azure_aadhybridhealth_adfs_service_delete.yml
#   inflating: sigma-master/rules/cloud/azure/azure_account_lockout.yml
#   inflating: sigma-master/rules/cloud/azure/azure_ad_user_added_to_admin_role.yml
#   inflating: sigma-master/rules/cloud/azure/azure_app_credential_modification.yml
#   inflating: sigma-master/rules/cloud/azure/azure_application_deleted.yml
#   inflating: sigma-master/rules/cloud/azure/azure_application_gateway_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/azure/azure_application_security_group_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/azure/azure_change_to_authentication_method.yml
#   inflating: sigma-master/rules/cloud/azure/azure_container_registry_created_or_deleted.yml
#   inflating: sigma-master/rules/cloud/azure/azure_creating_number_of_resources_detection.yml
#   inflating: sigma-master/rules/cloud/azure/azure_device_no_longer_managed_or_compliant.yml
#   inflating: sigma-master/rules/cloud/azure/azure_device_or_configuration_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/azure/azure_dns_zone_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/azure/azure_federation_modified.yml
#   inflating: sigma-master/rules/cloud/azure/azure_firewall_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/azure/azure_firewall_rule_collection_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/azure/azure_granting_permission_detection.yml
#   inflating: sigma-master/rules/cloud/azure/azure_keyvault_key_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/azure/azure_keyvault_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/azure/azure_keyvault_secrets_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/azure/azure_kubernetes_cluster_created_or_deleted.yml
#   inflating: sigma-master/rules/cloud/azure/azure_kubernetes_cronjob.yml
#   inflating: sigma-master/rules/cloud/azure/azure_kubernetes_events_deleted.yml
#   inflating: sigma-master/rules/cloud/azure/azure_kubernetes_network_policy_change.yml
#   inflating: sigma-master/rules/cloud/azure/azure_kubernetes_pods_deleted.yml
#   inflating: sigma-master/rules/cloud/azure/azure_kubernetes_role_access.yml
#   inflating: sigma-master/rules/cloud/azure/azure_kubernetes_rolebinding_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/azure/azure_kubernetes_secret_or_config_object_access.yml
#   inflating: sigma-master/rules/cloud/azure/azure_kubernetes_service_account_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/azure/azure_login_to_disabled_account.yml
#   inflating: sigma-master/rules/cloud/azure/azure_mfa_interrupted.yml
#   inflating: sigma-master/rules/cloud/azure/azure_network_firewall_policy_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/azure/azure_network_firewall_rule_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/azure/azure_network_p2s_vpn_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/azure/azure_network_security_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/azure/azure_network_virtual_device_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/azure/azure_new_cloudshell_created.yml
#   inflating: sigma-master/rules/cloud/azure/azure_owner_removed_from_application_or_service_principal.yml
#   inflating: sigma-master/rules/cloud/azure/azure_rare_operations.yml
#   inflating: sigma-master/rules/cloud/azure/azure_service_principal_created.yml
#   inflating: sigma-master/rules/cloud/azure/azure_service_principal_removed.yml
#   inflating: sigma-master/rules/cloud/azure/azure_suppression_rule_created.yml
#   inflating: sigma-master/rules/cloud/azure/azure_user_login_blocked_by_conditional_access.yml
#   inflating: sigma-master/rules/cloud/azure/azure_virtual_network_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/azure/azure_vpn_connection_modified_or_deleted.yml
#    creating: sigma-master/rules/cloud/gcp/
#   inflating: sigma-master/rules/cloud/gcp/gcp_bucket_enumeration.yml
#   inflating: sigma-master/rules/cloud/gcp/gcp_bucket_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/gcp/gcp_dlp_re_identifies_sensitive_information.yml
#   inflating: sigma-master/rules/cloud/gcp/gcp_dns_zone_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/gcp/gcp_firewall_rule_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/gcp/gcp_full_network_traffic_packet_capture.yml
#   inflating: sigma-master/rules/cloud/gcp/gcp_kubernetes_cronjob.yml
#   inflating: sigma-master/rules/cloud/gcp/gcp_kubernetes_rolebinding.yml
#   inflating: sigma-master/rules/cloud/gcp/gcp_kubernetes_secrets_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/gcp/gcp_service_account_disabled_or_deleted.yml
#   inflating: sigma-master/rules/cloud/gcp/gcp_service_account_modified.yml
#   inflating: sigma-master/rules/cloud/gcp/gcp_sql_database_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/gcp/gcp_vpn_tunnel_modified_or_deleted.yml
#    creating: sigma-master/rules/cloud/gworkspace/
#   inflating: sigma-master/rules/cloud/gworkspace/gworkspace_application_removed.yml
#   inflating: sigma-master/rules/cloud/gworkspace/gworkspace_granted_domain_api_access.yml
#   inflating: sigma-master/rules/cloud/gworkspace/gworkspace_mfa_disabled.yml
#   inflating: sigma-master/rules/cloud/gworkspace/gworkspace_role_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/gworkspace/gworkspace_role_privilege_deleted.yml
#   inflating: sigma-master/rules/cloud/gworkspace/gworkspace_user_granted_admin_privileges.yml
#    creating: sigma-master/rules/cloud/m365/
#   inflating: sigma-master/rules/cloud/m365/microsoft365_activity_by_terminated_user.yml
#   inflating: sigma-master/rules/cloud/m365/microsoft365_activity_from_anonymous_ip_addresses.yml
#   inflating: sigma-master/rules/cloud/m365/microsoft365_activity_from_infrequent_country.yml
#   inflating: sigma-master/rules/cloud/m365/microsoft365_data_exfiltration_to_unsanctioned_app.yml
#   inflating: sigma-master/rules/cloud/m365/microsoft365_from_suspicious_ip_addresses.yml
#   inflating: sigma-master/rules/cloud/m365/microsoft365_impossible_travel_activity.yml
#   inflating: sigma-master/rules/cloud/m365/microsoft365_logon_from_risky_ip_address.yml
#   inflating: sigma-master/rules/cloud/m365/microsoft365_potential_ransomware_activity.yml
#   inflating: sigma-master/rules/cloud/m365/microsoft365_suspicious_inbox_forwarding.yml
#   inflating: sigma-master/rules/cloud/m365/microsoft365_suspicious_oauth_app_file_download_activities.yml
#   inflating: sigma-master/rules/cloud/m365/microsoft365_unusual_volume_of_file_deletion.yml
#   inflating: sigma-master/rules/cloud/m365/microsoft365_user_restricted_from_sending_email.yml
#    creating: sigma-master/rules/cloud/okta/
#   inflating: sigma-master/rules/cloud/okta/okta_admin_role_assigned_to_user_or_group.yml
#   inflating: sigma-master/rules/cloud/okta/okta_api_token_created.yml
#   inflating: sigma-master/rules/cloud/okta/okta_api_token_revoked.yml
#   inflating: sigma-master/rules/cloud/okta/okta_application_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/okta/okta_application_sign_on_policy_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/okta/okta_mfa_reset_or_deactivated.yml
#   inflating: sigma-master/rules/cloud/okta/okta_network_zone_deactivated_or_deleted.yml
#   inflating: sigma-master/rules/cloud/okta/okta_policy_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/okta/okta_policy_rule_modified_or_deleted.yml
#   inflating: sigma-master/rules/cloud/okta/okta_security_threat_detected.yml
#   inflating: sigma-master/rules/cloud/okta/okta_unauthorized_access_to_app.yml
#   inflating: sigma-master/rules/cloud/okta/okta_user_account_locked_out.yml
#    creating: sigma-master/rules/cloud/onelogin/
#   inflating: sigma-master/rules/cloud/onelogin/onelogin_assumed_another_user.yml
#   inflating: sigma-master/rules/cloud/onelogin/onelogin_user_account_locked.yml
#    creating: sigma-master/rules/compliance/
#   inflating: sigma-master/rules/compliance/default_credentials_usage.yml
#   inflating: sigma-master/rules/compliance/firewall_cleartext_protocols.yml
#   inflating: sigma-master/rules/compliance/group_modification_logging.yml
#   inflating: sigma-master/rules/compliance/host_without_firewall.yml
#   inflating: sigma-master/rules/compliance/netflow_cleartext_protocols.yml
#   inflating: sigma-master/rules/compliance/workstation_was_locked.yml
#    creating: sigma-master/rules/generic/
#   inflating: sigma-master/rules/generic/generic_brute_force.yml
#    creating: sigma-master/rules/linux/
#    creating: sigma-master/rules/linux/auditd/
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_alter_bash_profile.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_audio_capture.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_auditing_config_change.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_binary_padding.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_change_file_time_attr.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_chattr_immutable_removal.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_clipboard_collection.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_clipboard_image_collection.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_coinminer.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_create_account.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_cve_2021_3156_sudo_buffer_overflow.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_cve_2021_3156_sudo_buffer_overflow_brutforce.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_data_exfil_wget.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_dd_delete_file.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_file_or_folder_permissions.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_find_cred_in_files.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_hidden_files_directories.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_hidden_zip_files_steganography.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_ld_so_preload_mod.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_load_module_insmod.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_logging_config_change.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_masquerading_crond.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_network_service_scanning.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_omigod_scx_runasprovider_executeshellcommand.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_password_policy_discovery.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_pers_systemd_reload.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_screencapture_import.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_screencaputre_xwd.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_split_file_into_pieces.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_steghide_embed_steganography.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_steghide_extract_steganography.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_susp_c2_commands.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_susp_cmds.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_susp_exe_folders.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_susp_histfile_operations.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_system_info_discovery.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_system_info_discovery2.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_system_shutdown_reboot.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_unzip_hidden_zip_files_steganography.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_user_discovery.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_auditd_web_rce.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_data_compressed.yml
#   inflating: sigma-master/rules/linux/auditd/lnx_network_sniffing.yml
#    creating: sigma-master/rules/linux/builtin/
#   inflating: sigma-master/rules/linux/builtin/lnx_apt_equationgroup_lnx.yml
#   inflating: sigma-master/rules/linux/builtin/lnx_buffer_overflows.yml
#   inflating: sigma-master/rules/linux/builtin/lnx_clear_syslog.yml
#   inflating: sigma-master/rules/linux/builtin/lnx_file_copy.yml
#   inflating: sigma-master/rules/linux/builtin/lnx_ldso_preload_injection.yml
#   inflating: sigma-master/rules/linux/builtin/lnx_proxy_connection.yml
#   inflating: sigma-master/rules/linux/builtin/lnx_setgid_setuid.yml
#   inflating: sigma-master/rules/linux/builtin/lnx_shell_clear_cmd_history.yml
#   inflating: sigma-master/rules/linux/builtin/lnx_shell_priv_esc_prep.yml
#   inflating: sigma-master/rules/linux/builtin/lnx_shell_susp_commands.yml
#   inflating: sigma-master/rules/linux/builtin/lnx_shell_susp_log_entries.yml
#   inflating: sigma-master/rules/linux/builtin/lnx_shell_susp_rev_shells.yml
#   inflating: sigma-master/rules/linux/builtin/lnx_shellshock.yml
#   inflating: sigma-master/rules/linux/builtin/lnx_space_after_filename_.yml
#   inflating: sigma-master/rules/linux/builtin/lnx_sudo_cve_2019_14287.yml
#   inflating: sigma-master/rules/linux/builtin/lnx_sudo_cve_2019_14287_user.yml
#   inflating: sigma-master/rules/linux/builtin/lnx_susp_jexboss.yml
#   inflating: sigma-master/rules/linux/builtin/lnx_symlink_etc_passwd.yml
#    creating: sigma-master/rules/linux/file_create/
#   inflating: sigma-master/rules/linux/file_create/cron_files.yml
#    creating: sigma-master/rules/linux/macos/
#    creating: sigma-master/rules/linux/macos/file_event/
#   inflating: sigma-master/rules/linux/macos/file_event/macos_emond_launch_daemon.yml
#   inflating: sigma-master/rules/linux/macos/file_event/macos_startup_items.yml
#    creating: sigma-master/rules/linux/macos/process_creation/
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_applescript.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_base64_decode.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_binary_padding.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_change_file_time_attr.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_clear_system_logs.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_create_account.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_create_hidden_account.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_creds_from_keychain.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_disable_security_tools.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_file_and_directory_discovery.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_find_cred_in_files.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_gui_input_capture.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_local_account.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_local_groups.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_network_service_scanning.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_network_sniffing.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_remote_system_discovery.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_schedule_task_job_cron.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_screencapture.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_security_software_discovery.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_space_after_filename.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_split_file_into_pieces.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_susp_histfile_operations.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_suspicious_macos_firmware_activity.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_system_network_connections_discovery.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_system_network_discovery.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_system_shutdown_reboot.yml
#   inflating: sigma-master/rules/linux/macos/process_creation/macos_xattr_gatekeeper_bypass.yml
#    creating: sigma-master/rules/linux/modsecurity/
#   inflating: sigma-master/rules/linux/modsecurity/modsec_mulitple_blocks.yml
#    creating: sigma-master/rules/linux/network_connection/
#   inflating: sigma-master/rules/linux/network_connection/lnx_back_connect_shell_dev.yml
#   inflating: sigma-master/rules/linux/network_connection/lnx_crypto_mining_indicators.yml
#    creating: sigma-master/rules/linux/other/
#   inflating: sigma-master/rules/linux/other/lnx_clamav.yml
#   inflating: sigma-master/rules/linux/other/lnx_security_tools_disabling_syslog.yml
#   inflating: sigma-master/rules/linux/other/lnx_ssh_cve_2018_15473.yml
#   inflating: sigma-master/rules/linux/other/lnx_susp_failed_logons_single_source.yml
#   inflating: sigma-master/rules/linux/other/lnx_susp_guacamole.yml
#   inflating: sigma-master/rules/linux/other/lnx_susp_named.yml
#   inflating: sigma-master/rules/linux/other/lnx_susp_ssh.yml
#   inflating: sigma-master/rules/linux/other/lnx_susp_vsftp.yml
#    creating: sigma-master/rules/linux/process_creation/
#   inflating: sigma-master/rules/linux/process_creation/at_command.yml
#   inflating: sigma-master/rules/linux/process_creation/clear_syslog.yml
#   inflating: sigma-master/rules/linux/process_creation/clipboard_collection.yml
#   inflating: sigma-master/rules/linux/process_creation/dd_file_overwrite.yml
#   inflating: sigma-master/rules/linux/process_creation/lnx_base64_decode.yml
#   inflating: sigma-master/rules/linux/process_creation/lnx_clear_logs.yml
#   inflating: sigma-master/rules/linux/process_creation/lnx_crypto_mining.yml
#   inflating: sigma-master/rules/linux/process_creation/lnx_file_and_directory_discovery.yml
#   inflating: sigma-master/rules/linux/process_creation/lnx_file_deletion.yml
#   inflating: sigma-master/rules/linux/process_creation/lnx_install_root_certificate.yml
#   inflating: sigma-master/rules/linux/process_creation/lnx_local_account.yml
#   inflating: sigma-master/rules/linux/process_creation/lnx_local_groups.yml
#   inflating: sigma-master/rules/linux/process_creation/lnx_network_service_scanning.yml
#   inflating: sigma-master/rules/linux/process_creation/lnx_process_discovery.yml
#   inflating: sigma-master/rules/linux/process_creation/lnx_remote_system_discovery.yml
#   inflating: sigma-master/rules/linux/process_creation/lnx_schedule_task_job_cron.yml
#   inflating: sigma-master/rules/linux/process_creation/lnx_security_software_discovery.yml
#   inflating: sigma-master/rules/linux/process_creation/lnx_security_tools_disabling.yml
#   inflating: sigma-master/rules/linux/process_creation/lnx_system_info_discovery.yml
#   inflating: sigma-master/rules/linux/process_creation/lnx_system_network_connections_discovery.yml
#   inflating: sigma-master/rules/linux/process_creation/lnx_system_network_discovery.yml
#   inflating: sigma-master/rules/linux/process_creation/lnx_webshell_detection.yml
#   inflating: sigma-master/rules/linux/process_creation/omigod_scx_runasprovider_executescript.yml
#   inflating: sigma-master/rules/linux/process_creation/omigod_scx_runasprovider_executeshellcommand.yml
#    creating: sigma-master/rules/network/
#    creating: sigma-master/rules/network/cisco/
#    creating: sigma-master/rules/network/cisco/aaa/
#   inflating: sigma-master/rules/network/cisco/aaa/cisco_cli_clear_logs.yml
#   inflating: sigma-master/rules/network/cisco/aaa/cisco_cli_collect_data.yml
#   inflating: sigma-master/rules/network/cisco/aaa/cisco_cli_crypto_actions.yml
#   inflating: sigma-master/rules/network/cisco/aaa/cisco_cli_disable_logging.yml
#   inflating: sigma-master/rules/network/cisco/aaa/cisco_cli_discovery.yml
#   inflating: sigma-master/rules/network/cisco/aaa/cisco_cli_dos.yml
#   inflating: sigma-master/rules/network/cisco/aaa/cisco_cli_file_deletion.yml
#   inflating: sigma-master/rules/network/cisco/aaa/cisco_cli_input_capture.yml
#   inflating: sigma-master/rules/network/cisco/aaa/cisco_cli_local_accounts.yml
#   inflating: sigma-master/rules/network/cisco/aaa/cisco_cli_modify_config.yml
#   inflating: sigma-master/rules/network/cisco/aaa/cisco_cli_moving_data.yml
#   inflating: sigma-master/rules/network/cisco/aaa/cisco_cli_net_sniff.yml
#   inflating: sigma-master/rules/network/net_apt_equationgroup_c2.yml
#   inflating: sigma-master/rules/network/net_dns_c2_detection.yml
#   inflating: sigma-master/rules/network/net_firewall_high_dns_bytes_out.yml
#   inflating: sigma-master/rules/network/net_firewall_high_dns_requests_rate.yml
#   inflating: sigma-master/rules/network/net_high_dns_bytes_out.yml
#   inflating: sigma-master/rules/network/net_high_dns_requests_rate.yml
#   inflating: sigma-master/rules/network/net_high_null_records_requests_rate.yml
#   inflating: sigma-master/rules/network/net_high_txt_records_requests_rate.yml
#   inflating: sigma-master/rules/network/net_mal_dns_cobaltstrike.yml
#   inflating: sigma-master/rules/network/net_pua_cryptocoin_mining_xmr.yml
#   inflating: sigma-master/rules/network/net_susp_dns_b64_queries.yml
#   inflating: sigma-master/rules/network/net_susp_dns_txt_exec_strings.yml
#   inflating: sigma-master/rules/network/net_susp_network_scan_by_ip.yml
#   inflating: sigma-master/rules/network/net_susp_network_scan_by_port.yml
#   inflating: sigma-master/rules/network/net_susp_telegram_api.yml
#   inflating: sigma-master/rules/network/net_wannacry_killswitch_domain.yml
#    creating: sigma-master/rules/network/zeek/
#   inflating: sigma-master/rules/network/zeek/zeek_dce_rpc_domain_user_enumeration.yml
#   inflating: sigma-master/rules/network/zeek/zeek_dce_rpc_mitre_bzar_execution.yml
#   inflating: sigma-master/rules/network/zeek/zeek_dce_rpc_mitre_bzar_persistence.yml
#   inflating: sigma-master/rules/network/zeek/zeek_dce_rpc_potential_petit_potam_efs_rpc_call.yml
#   inflating: sigma-master/rules/network/zeek/zeek_dce_rpc_printnightmare_print_driver_install.yml
#   inflating: sigma-master/rules/network/zeek/zeek_dce_rpc_smb_spoolss_named_pipe.yml
#   inflating: sigma-master/rules/network/zeek/zeek_default_cobalt_strike_certificate.yml
#   inflating: sigma-master/rules/network/zeek/zeek_dns_mining_pools.yml
#   inflating: sigma-master/rules/network/zeek/zeek_dns_suspicious_zbit_flag.yml
#   inflating: sigma-master/rules/network/zeek/zeek_dns_torproxy.yml
#   inflating: sigma-master/rules/network/zeek/zeek_http_executable_download_from_webdav.yml
#   inflating: sigma-master/rules/network/zeek/zeek_http_omigod_no_auth_rce.yml
#   inflating: sigma-master/rules/network/zeek/zeek_http_webdav_put_request.yml
#   inflating: sigma-master/rules/network/zeek/zeek_rdp_public_listener.yml
#   inflating: sigma-master/rules/network/zeek/zeek_smb_converted_win_atsvc_task.yml
#   inflating: sigma-master/rules/network/zeek/zeek_smb_converted_win_impacket_secretdump.yml
#   inflating: sigma-master/rules/network/zeek/zeek_smb_converted_win_lm_namedpipe.yml
#   inflating: sigma-master/rules/network/zeek/zeek_smb_converted_win_susp_psexec.yml
#   inflating: sigma-master/rules/network/zeek/zeek_smb_converted_win_susp_raccess_sensitive_fext.yml
#   inflating: sigma-master/rules/network/zeek/zeek_smb_converted_win_transferring_files_with_credential_data.yml
#   inflating: sigma-master/rules/network/zeek/zeek_susp_kerberos_rc4.yml
#    creating: sigma-master/rules/proxy/
#   inflating: sigma-master/rules/proxy/proxy_apt40.yml
#   inflating: sigma-master/rules/proxy/proxy_apt_domestic_kitten.yml
#   inflating: sigma-master/rules/proxy/proxy_baby_shark.yml
#   inflating: sigma-master/rules/proxy/proxy_chafer_malware.yml
#   inflating: sigma-master/rules/proxy/proxy_cobalt_amazon.yml
#   inflating: sigma-master/rules/proxy/proxy_cobalt_malformed_uas.yml
#   inflating: sigma-master/rules/proxy/proxy_cobalt_ocsp.yml
#   inflating: sigma-master/rules/proxy/proxy_cobalt_onedrive.yml
#   inflating: sigma-master/rules/proxy/proxy_download_susp_dyndns.yml
#   inflating: sigma-master/rules/proxy/proxy_download_susp_tlds_blacklist.yml
#   inflating: sigma-master/rules/proxy/proxy_download_susp_tlds_whitelist.yml
#   inflating: sigma-master/rules/proxy/proxy_downloadcradle_webdav.yml
#   inflating: sigma-master/rules/proxy/proxy_empire_ua_uri_combos.yml
#   inflating: sigma-master/rules/proxy/proxy_empty_ua.yml
#   inflating: sigma-master/rules/proxy/proxy_ios_implant.yml
#   inflating: sigma-master/rules/proxy/proxy_powershell_ua.yml
#   inflating: sigma-master/rules/proxy/proxy_pwndrop.yml
#   inflating: sigma-master/rules/proxy/proxy_raw_paste_service_access.yml
#   inflating: sigma-master/rules/proxy/proxy_susp_flash_download_loc.yml
#   inflating: sigma-master/rules/proxy/proxy_telegram_api.yml
#   inflating: sigma-master/rules/proxy/proxy_turla_comrat.yml
#   inflating: sigma-master/rules/proxy/proxy_ua_apt.yml
#   inflating: sigma-master/rules/proxy/proxy_ua_bitsadmin_susp_tld.yml
#   inflating: sigma-master/rules/proxy/proxy_ua_cryptominer.yml
#   inflating: sigma-master/rules/proxy/proxy_ua_frameworks.yml
#   inflating: sigma-master/rules/proxy/proxy_ua_hacktool.yml
#   inflating: sigma-master/rules/proxy/proxy_ua_malware.yml
#   inflating: sigma-master/rules/proxy/proxy_ua_suspicious.yml
#   inflating: sigma-master/rules/proxy/proxy_ursnif_malware_c2_url.yml
#   inflating: sigma-master/rules/proxy/proxy_ursnif_malware_download_url.yml
#    creating: sigma-master/rules/web/
#   inflating: sigma-master/rules/web/sql_injection_keywords.yml
#   inflating: sigma-master/rules/web/web_apache_segfault.yml
#   inflating: sigma-master/rules/web/web_apache_threading_error.yml
#   inflating: sigma-master/rules/web/web_arcadyan_router_cve_2021_20090_2021_20091_exploit.yml
#   inflating: sigma-master/rules/web/web_citrix_cve_2019_19781_exploit.yml
#   inflating: sigma-master/rules/web/web_citrix_cve_2020_8193_8195_exploit.yml
#   inflating: sigma-master/rules/web/web_cve_2010_5278_exploitation_attempt.yml
#   inflating: sigma-master/rules/web/web_cve_2018_2894_weblogic_exploit.yml
#   inflating: sigma-master/rules/web/web_cve_2019_3398_confluence.yml
#   inflating: sigma-master/rules/web/web_cve_2020_0688_msexchange.yml
#   inflating: sigma-master/rules/web/web_cve_2020_14882_weblogic_exploit.yml
#   inflating: sigma-master/rules/web/web_cve_2020_3452_cisco_asa_ftd.yml
#   inflating: sigma-master/rules/web/web_cve_2020_5902_f5_bigip.yml
#   inflating: sigma-master/rules/web/web_cve_2021_2109_weblogic_rce_exploit.yml
#   inflating: sigma-master/rules/web/web_cve_2021_21978_vmware_view_planner_exploit.yml
#   inflating: sigma-master/rules/web/web_cve_2021_22005_vmware_file_upload.yml
#   inflating: sigma-master/rules/web/web_cve_2021_22893_pulse_secure_rce_exploit.yml
#   inflating: sigma-master/rules/web/web_cve_2021_26814_wzuh_rce.yml
#   inflating: sigma-master/rules/web/web_cve_2021_26858_iis_rce.yml
#   inflating: sigma-master/rules/web/web_cve_2021_33766_msexchange_proxytoken.yml
#   inflating: sigma-master/rules/web/web_cve_2021_40539_adselfservice.yml
#   inflating: sigma-master/rules/web/web_cve_2021_40539_manageengine_adselfservice_exploit.yml
#   inflating: sigma-master/rules/web/web_cve_2021_41773_apache_path_traversal.yml
#   inflating: sigma-master/rules/web/web_cve_2021_42237_sitecore_report_ashx.yml
#   inflating: sigma-master/rules/web/web_exchange_cve_2020_0688_exploit.yml
#   inflating: sigma-master/rules/web/web_exchange_exploitation_hafnium.yml
#   inflating: sigma-master/rules/web/web_exchange_proxyshell.yml
#   inflating: sigma-master/rules/web/web_exchange_proxyshell_successful.yml
#   inflating: sigma-master/rules/web/web_expl_exchange_cve_2021_28480.yml
#   inflating: sigma-master/rules/web/web_fortinet_cve_2018_13379_preauth_read_exploit.yml
#   inflating: sigma-master/rules/web/web_fortinet_cve_2021_22123_exploit.yml
#   inflating: sigma-master/rules/web/web_iis_tilt_shortname_scan.yml
#   inflating: sigma-master/rules/web/web_multiple_suspicious_resp_codes_single_source.yml
#   inflating: sigma-master/rules/web/web_nginx_core_dump.yml
#   inflating: sigma-master/rules/web/web_path_traversal_exploitation_attempt.yml
#   inflating: sigma-master/rules/web/web_pulsesecure_cve_2019_11510.yml
#   inflating: sigma-master/rules/web/web_solarwinds_cve_2020_10148.yml
#   inflating: sigma-master/rules/web/web_solarwinds_supernova_webshell.yml
#   inflating: sigma-master/rules/web/web_sonicwall_jarrewrite_exploit.yml
#   inflating: sigma-master/rules/web/web_source_code_enumeration.yml
#   inflating: sigma-master/rules/web/web_terramaster_cve_2020_28188_rce_exploit.yml
#   inflating: sigma-master/rules/web/web_unc2546_dewmode_php_webshell.yml
#   inflating: sigma-master/rules/web/web_vsphere_cve_2021_21972_unauth_rce_exploit.yml
#   inflating: sigma-master/rules/web/web_webshell_keyword.yml
#   inflating: sigma-master/rules/web/win_powershell_snapins_hafnium.yml
#   inflating: sigma-master/rules/web/win_webshell_regeorg.yml
#   inflating: sigma-master/rules/web/xss_keywords.yml
#    creating: sigma-master/rules/windows/
#    creating: sigma-master/rules/windows/builtin/
#   inflating: sigma-master/rules/windows/builtin/win_aadhealth_mon_agent_regkey_access.yml
#   inflating: sigma-master/rules/windows/builtin/win_aadhealth_svc_agent_regkey_access.yml
#   inflating: sigma-master/rules/windows/builtin/win_account_backdoor_dcsync_rights.yml
#   inflating: sigma-master/rules/windows/builtin/win_account_discovery.yml
#   inflating: sigma-master/rules/windows/builtin/win_ad_object_writedac_access.yml
#   inflating: sigma-master/rules/windows/builtin/win_ad_replication_non_machine_account.yml
#   inflating: sigma-master/rules/windows/builtin/win_ad_user_enumeration.yml
#   inflating: sigma-master/rules/windows/builtin/win_adcs_certificate_template_configuration_vulnerability.yml
#   inflating: sigma-master/rules/windows/builtin/win_adcs_certificate_template_configuration_vulnerability_eku.yml
#   inflating: sigma-master/rules/windows/builtin/win_admin_rdp_login.yml
#   inflating: sigma-master/rules/windows/builtin/win_admin_share_access.yml
#   inflating: sigma-master/rules/windows/builtin/win_alert_active_directory_user_control.yml
#   inflating: sigma-master/rules/windows/builtin/win_alert_ad_user_backdoors.yml
#   inflating: sigma-master/rules/windows/builtin/win_alert_enable_weak_encryption.yml
#   inflating: sigma-master/rules/windows/builtin/win_alert_lsass_access.yml
#   inflating: sigma-master/rules/windows/builtin/win_alert_mimikatz_keywords.yml
#   inflating: sigma-master/rules/windows/builtin/win_alert_ruler.yml
#   inflating: sigma-master/rules/windows/builtin/win_applocker_file_was_not_allowed_to_run.yml
#   inflating: sigma-master/rules/windows/builtin/win_apt_carbonpaper_turla.yml
#   inflating: sigma-master/rules/windows/builtin/win_apt_chafer_mar18_security.yml
#   inflating: sigma-master/rules/windows/builtin/win_apt_chafer_mar18_system.yml
#   inflating: sigma-master/rules/windows/builtin/win_apt_gallium.yml
#   inflating: sigma-master/rules/windows/builtin/win_apt_slingshot.yml
#   inflating: sigma-master/rules/windows/builtin/win_apt_stonedrill.yml
#   inflating: sigma-master/rules/windows/builtin/win_apt_turla_service_png.yml
#   inflating: sigma-master/rules/windows/builtin/win_apt_wocao.yml
#   inflating: sigma-master/rules/windows/builtin/win_arbitrary_shell_execution_via_settingcontent.yml
#   inflating: sigma-master/rules/windows/builtin/win_asr_bypass_via_appvlp_re.yml
#   inflating: sigma-master/rules/windows/builtin/win_atsvc_task.yml
#   inflating: sigma-master/rules/windows/builtin/win_audit_cve.yml
#   inflating: sigma-master/rules/windows/builtin/win_av_relevant_match.yml
#   inflating: sigma-master/rules/windows/builtin/win_camera_microphone_access.yml
#   inflating: sigma-master/rules/windows/builtin/win_cobaltstrike_service_installs.yml
#   inflating: sigma-master/rules/windows/builtin/win_dce_rpc_smb_spoolss_named_pipe.yml
#   inflating: sigma-master/rules/windows/builtin/win_dcom_iertutil_dll_hijack.yml
#   inflating: sigma-master/rules/windows/builtin/win_dcsync.yml
#   inflating: sigma-master/rules/windows/builtin/win_disable_event_logging.yml
#   inflating: sigma-master/rules/windows/builtin/win_dpapi_domain_backupkey_extraction.yml
#   inflating: sigma-master/rules/windows/builtin/win_dpapi_domain_masterkey_backup_attempt.yml
#   inflating: sigma-master/rules/windows/builtin/win_etw_modification.yml
#   inflating: sigma-master/rules/windows/builtin/win_event_log_cleared.yml
#   inflating: sigma-master/rules/windows/builtin/win_exchange_transportagent.yml
#   inflating: sigma-master/rules/windows/builtin/win_exploit_cve_2021_1675_printspooler.yml
#   inflating: sigma-master/rules/windows/builtin/win_exploit_cve_2021_1675_printspooler_operational.yml
#   inflating: sigma-master/rules/windows/builtin/win_exploit_cve_2021_1675_printspooler_security.yml
#   inflating: sigma-master/rules/windows/builtin/win_external_device.yml
#   inflating: sigma-master/rules/windows/builtin/win_global_catalog_enumeration.yml
#   inflating: sigma-master/rules/windows/builtin/win_gpo_scheduledtasks.yml
#   inflating: sigma-master/rules/windows/builtin/win_hack_smbexec.yml
#   inflating: sigma-master/rules/windows/builtin/win_hidden_user_creation.yml
#   inflating: sigma-master/rules/windows/builtin/win_hybridconnectionmgr_svc_installation.yml
#   inflating: sigma-master/rules/windows/builtin/win_hybridconnectionmgr_svc_running.yml
#   inflating: sigma-master/rules/windows/builtin/win_impacket_psexec.yml
#   inflating: sigma-master/rules/windows/builtin/win_impacket_secretdump.yml
#   inflating: sigma-master/rules/windows/builtin/win_invoke_obfuscation_clip_services.yml
#   inflating: sigma-master/rules/windows/builtin/win_invoke_obfuscation_clip_services_security.yml
#   inflating: sigma-master/rules/windows/builtin/win_invoke_obfuscation_obfuscated_iex_services.yml
#   inflating: sigma-master/rules/windows/builtin/win_invoke_obfuscation_obfuscated_iex_services_security.yml
#   inflating: sigma-master/rules/windows/builtin/win_invoke_obfuscation_stdin_services.yml
#   inflating: sigma-master/rules/windows/builtin/win_invoke_obfuscation_stdin_services_security.yml
#   inflating: sigma-master/rules/windows/builtin/win_invoke_obfuscation_var_services.yml
#   inflating: sigma-master/rules/windows/builtin/win_invoke_obfuscation_var_services_security.yml
#   inflating: sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_compress_services.yml
#   inflating: sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_compress_services_security.yml
#   inflating: sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_rundll_services.yml
#   inflating: sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_rundll_services_security.yml
#   inflating: sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_stdin_services.yml
#   inflating: sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_stdin_services_security.yml
#   inflating: sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_use_clip_services.yml
#   inflating: sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_use_clip_services_security.yml
#   inflating: sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_use_mshta_services.yml
#   inflating: sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_use_mshta_services_security.yml
#   inflating: sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_use_rundll32_services.yml
#   inflating: sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_use_rundll32_services_security.yml
#   inflating: sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_var_services.yml
#   inflating: sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_var_services_security.yml
#   inflating: sigma-master/rules/windows/builtin/win_iso_mount.yml
#   inflating: sigma-master/rules/windows/builtin/win_lm_namedpipe.yml
#   inflating: sigma-master/rules/windows/builtin/win_lolbas_execution_of_nltest.yml
#   inflating: sigma-master/rules/windows/builtin/win_lsass_access_non_system_account.yml
#   inflating: sigma-master/rules/windows/builtin/win_mal_creddumper.yml
#   inflating: sigma-master/rules/windows/builtin/win_mal_wceaux_dll.yml
#   inflating: sigma-master/rules/windows/builtin/win_metasploit_authentication.yml
#   inflating: sigma-master/rules/windows/builtin/win_meterpreter_or_cobaltstrike_getsystem_service_installation.yml
#   inflating: sigma-master/rules/windows/builtin/win_mmc20_lateral_movement.yml
#   inflating: sigma-master/rules/windows/builtin/win_moriya_rootkit.yml
#   inflating: sigma-master/rules/windows/builtin/win_net_ntlm_downgrade.yml
#   inflating: sigma-master/rules/windows/builtin/win_net_use_admin_share.yml
#   inflating: sigma-master/rules/windows/builtin/win_new_or_renamed_user_account_with_dollar_sign.yml
#   inflating: sigma-master/rules/windows/builtin/win_not_allowed_rdp_access.yml
#   inflating: sigma-master/rules/windows/builtin/win_ntfs_vuln_exploit.yml
#   inflating: sigma-master/rules/windows/builtin/win_overpass_the_hash.yml
#   inflating: sigma-master/rules/windows/builtin/win_pass_the_hash.yml
#   inflating: sigma-master/rules/windows/builtin/win_pass_the_hash_2.yml
#   inflating: sigma-master/rules/windows/builtin/win_petitpotam_network_share.yml
#   inflating: sigma-master/rules/windows/builtin/win_petitpotam_susp_tgt_request.yml
#   inflating: sigma-master/rules/windows/builtin/win_possible_dc_shadow.yml
#   inflating: sigma-master/rules/windows/builtin/win_powershell_script_installed_as_service.yml
#   inflating: sigma-master/rules/windows/builtin/win_privesc_cve_2020_1472.yml
# ...
#   inflating: sigma-master/rules/windows/registry_event/sysmon_office_test_regadd.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_office_vsto_persistence.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_powershell_as_service.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_rdp_registry_modification.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_rdp_settings_hijack.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_redmimicry_winnti_reg.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_reg_office_security.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_reg_silentprocessexit.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_reg_silentprocessexit_lsass.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_reg_vbs_payload_stored.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_registry_add_local_hidden_user.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_registry_persistence_key_linking.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_registry_persistence_search_order.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_registry_susp_printer_driver.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_registry_trust_record_modification.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_removal_amsi_registry_key.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_removal_com_hijacking_registry_key.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_runkey_winekey.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_runonce_persistence.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_ssp_added_lsa_config.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_susp_atbroker_change.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_susp_download_run_key.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_susp_lsass_dll_load.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_susp_mic_cam_access.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_susp_reg_persist_explorer_run.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_susp_run_key_img_folder.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_susp_service_installed.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_suspicious_keyboard_layout_load.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_sysinternals_sdelete_registry_keys.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_taskcache_entry.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_uac_bypass_sdclt.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_volume_shadow_copy_service_keys.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_wab_dllpath_reg_change.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_wdigest_enable_uselogoncredential.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_win_reg_persistence.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_win_reg_persistence_recycle_bin.yml
#   inflating: sigma-master/rules/windows/registry_event/sysmon_win_reg_telemetry_persistence.yml
#   inflating: sigma-master/rules/windows/registry_event/win_outlook_c2_registry_key.yml
#   inflating: sigma-master/rules/windows/registry_event/win_outlook_registry_todaypage.yml
#   inflating: sigma-master/rules/windows/registry_event/win_outlook_registry_webview.yml
#   inflating: sigma-master/rules/windows/registry_event/win_portproxy_registry_key.yml
#   inflating: sigma-master/rules/windows/registry_event/win_registry_file_association_exefile.yml
#   inflating: sigma-master/rules/windows/registry_event/win_registry_mimikatz_printernightmare.yml
#   inflating: sigma-master/rules/windows/registry_event/win_registry_shell_open_keys_manipulation.yml
#    creating: sigma-master/rules/windows/sysmon/
#   inflating: sigma-master/rules/windows/sysmon/sysmon_accessing_winapi_in_powershell_credentials_dumping.yml
#   inflating: sigma-master/rules/windows/sysmon/sysmon_config_modification_error.yml
#   inflating: sigma-master/rules/windows/sysmon/sysmon_config_modification_status.yml
#   inflating: sigma-master/rules/windows/sysmon/sysmon_dcom_iertutil_dll_hijack.yml
#    creating: sigma-master/rules/windows/wmi_event/
#   inflating: sigma-master/rules/windows/wmi_event/sysmon_wmi_event_subscription.yml
#   inflating: sigma-master/rules/windows/wmi_event/sysmon_wmi_susp_encoded_scripts.yml
#   inflating: sigma-master/rules/windows/wmi_event/sysmon_wmi_susp_scripting.yml
#   inflating: sigma-master/sigma-schema.rx.yml
#    creating: sigma-master/tests/
#  extracting: sigma-master/tests/backend_config.yml
#   inflating: sigma-master/tests/collection_repeat.yml
#   inflating: sigma-master/tests/config-multiple_mapping-2.yml
#   inflating: sigma-master/tests/config-multiple_mapping.yml
#   inflating: sigma-master/tests/es-query-template.jq
#   inflating: sigma-master/tests/invalid_config.yml
#   inflating: sigma-master/tests/invalid_sigma-invalid_aggregation.yml
#   inflating: sigma-master/tests/invalid_sigma-invalid_identifier_reference.yml
#   inflating: sigma-master/tests/invalid_sigma-no_condition.yml
#   inflating: sigma-master/tests/invalid_sigma-no_identifiers.yml
#   inflating: sigma-master/tests/invalid_sigma-wrong_identifier_definition.yml
#  extracting: sigma-master/tests/invalid_yaml.badyml
#   inflating: sigma-master/tests/mapping-conditional-multi.yml
#   inflating: sigma-master/tests/test-backend-es-qs.py
#   inflating: sigma-master/tests/test-backend-netwitness.py
#   inflating: sigma-master/tests/test-merge.sh
#   inflating: sigma-master/tests/test-modifiers.yml
#   inflating: sigma-master/tests/test_rules.py
#    creating: sigma-master/tools/
#   inflating: sigma-master/tools/LICENSE.LGPL.txt
#   inflating: sigma-master/tools/LONG_DESCRIPTION.md
#   inflating: sigma-master/tools/MANIFEST.in
#   inflating: sigma-master/tools/README.md
#    creating: sigma-master/tools/config/
#   inflating: sigma-master/tools/config/ala-azure-activitylogs.yml
#   inflating: sigma-master/tools/config/ala-azure-ad_auditlogs.yml
#   inflating: sigma-master/tools/config/ala-azure-aws_cloudtrail.yml
#   inflating: sigma-master/tools/config/ala-suricata.yml
#   inflating: sigma-master/tools/config/ala.yml
#   inflating: sigma-master/tools/config/arcsight-zeek.yml
#   inflating: sigma-master/tools/config/arcsight.yml
#   inflating: sigma-master/tools/config/athena.yml
#   inflating: sigma-master/tools/config/carbon-black-eedr.yml
#   inflating: sigma-master/tools/config/carbon-black.yml
#   inflating: sigma-master/tools/config/chronicle.yml
#   inflating: sigma-master/tools/config/crowdstrike.yml
#   inflating: sigma-master/tools/config/devo-network.yml
#   inflating: sigma-master/tools/config/devo-web.yml
#   inflating: sigma-master/tools/config/devo-windows.yml
#   inflating: sigma-master/tools/config/ecs-auditbeat-modules-enabled.yml
#   inflating: sigma-master/tools/config/ecs-auditd.yml
#   inflating: sigma-master/tools/config/ecs-azure-activitylogs.yml
#   inflating: sigma-master/tools/config/ecs-azure-ad_auditlogs.yml
#   inflating: sigma-master/tools/config/ecs-azure-ad_signinlogs.yml
#   inflating: sigma-master/tools/config/ecs-cloudtrail.yml
#   inflating: sigma-master/tools/config/ecs-dns.yml
#   inflating: sigma-master/tools/config/ecs-filebeat.yml
#   inflating: sigma-master/tools/config/ecs-ms365_defender.yml
#   inflating: sigma-master/tools/config/ecs-okta.yml
#   inflating: sigma-master/tools/config/ecs-proxy.yml
#   inflating: sigma-master/tools/config/ecs-suricata.yml
#   inflating: sigma-master/tools/config/ecs-zeek-corelight.yml
#   inflating: sigma-master/tools/config/ecs-zeek-elastic-beats-implementation.yml
#   inflating: sigma-master/tools/config/elk-defaultindex-filebeat.yml
#   inflating: sigma-master/tools/config/elk-defaultindex-logstash.yml
#   inflating: sigma-master/tools/config/elk-defaultindex.yml
#   inflating: sigma-master/tools/config/elk-linux.yml
#   inflating: sigma-master/tools/config/elk-windows.yml
#   inflating: sigma-master/tools/config/elk-winlogbeat-sp.yml
#   inflating: sigma-master/tools/config/elk-winlogbeat.yml
#   inflating: sigma-master/tools/config/filebeat-defaultindex.yml
#   inflating: sigma-master/tools/config/fireeye-helix.yml
#    creating: sigma-master/tools/config/generic/
#   inflating: sigma-master/tools/config/generic/m365.yml
#   inflating: sigma-master/tools/config/generic/powershell.yml
#   inflating: sigma-master/tools/config/generic/sysmon.yml
#   inflating: sigma-master/tools/config/generic/windows-audit.yml
#   inflating: sigma-master/tools/config/hawk.yml
#   inflating: sigma-master/tools/config/helk.yml
#   inflating: sigma-master/tools/config/humio.yml
#   inflating: sigma-master/tools/config/limacharlie.yml
#   inflating: sigma-master/tools/config/logpoint-windows.yml
#   inflating: sigma-master/tools/config/logrhythm_winevent.yml
#   inflating: sigma-master/tools/config/logstash-defaultindex.yml
#   inflating: sigma-master/tools/config/logstash-linux.yml
#   inflating: sigma-master/tools/config/logstash-windows.yml
#   inflating: sigma-master/tools/config/logstash-zeek-default-json.yml
#    creating: sigma-master/tools/config/mitre/
#   inflating: sigma-master/tools/config/mitre/tactics.json
#   inflating: sigma-master/tools/config/mitre/techniques.json
#   inflating: sigma-master/tools/config/mitre/update_mitre.py
#   inflating: sigma-master/tools/config/netwitness-epl.yml
#   inflating: sigma-master/tools/config/netwitness.yml
#   inflating: sigma-master/tools/config/powershell.yml
#   inflating: sigma-master/tools/config/qradar.yml
#   inflating: sigma-master/tools/config/qualys.yml
#   inflating: sigma-master/tools/config/splunk-windows-index.yml
#   inflating: sigma-master/tools/config/splunk-windows.yml
#   inflating: sigma-master/tools/config/splunk-zeek.yml
#   inflating: sigma-master/tools/config/stix-custom.yml
#   inflating: sigma-master/tools/config/stix-shifter.yml
#   inflating: sigma-master/tools/config/stix2.0.yml
#   inflating: sigma-master/tools/config/sumologic-cse.yml
#   inflating: sigma-master/tools/config/sumologic.yml
#   inflating: sigma-master/tools/config/thor.yml
#   inflating: sigma-master/tools/config/winlogbeat-modules-enabled.yml
#   inflating: sigma-master/tools/config/winlogbeat-old.yml
#   inflating: sigma-master/tools/config/winlogbeat.yml
#   inflating: sigma-master/tools/merge_sigma
#  extracting: sigma-master/tools/setup.cfg
#   inflating: sigma-master/tools/setup.py
#    creating: sigma-master/tools/sigma/
#  extracting: sigma-master/tools/sigma/__init__.py
#    creating: sigma-master/tools/sigma/backends/
#   inflating: sigma-master/tools/sigma/backends/ala.py
#   inflating: sigma-master/tools/sigma/backends/arcsight.py
#   inflating: sigma-master/tools/sigma/backends/athena.py
#   inflating: sigma-master/tools/sigma/backends/base.py
#   inflating: sigma-master/tools/sigma/backends/carbonblack.py
#   inflating: sigma-master/tools/sigma/backends/chronicle.py
#   inflating: sigma-master/tools/sigma/backends/cim.py
#   inflating: sigma-master/tools/sigma/backends/csharp.py
#   inflating: sigma-master/tools/sigma/backends/data.py
#   inflating: sigma-master/tools/sigma/backends/devo.py
#   inflating: sigma-master/tools/sigma/backends/discovery.py
#   inflating: sigma-master/tools/sigma/backends/ee-outliers.py
#   inflating: sigma-master/tools/sigma/backends/elasticsearch.py
#   inflating: sigma-master/tools/sigma/backends/exceptions.py
#   inflating: sigma-master/tools/sigma/backends/fireeye-helix.py
#   inflating: sigma-master/tools/sigma/backends/graylog.py
#   inflating: sigma-master/tools/sigma/backends/hawk.py
#   inflating: sigma-master/tools/sigma/backends/humio.py
#   inflating: sigma-master/tools/sigma/backends/lacework.py
#   inflating: sigma-master/tools/sigma/backends/limacharlie.py
#   inflating: sigma-master/tools/sigma/backends/logiq.py
#   inflating: sigma-master/tools/sigma/backends/logpoint.py
#   inflating: sigma-master/tools/sigma/backends/mdatp.py
#   inflating: sigma-master/tools/sigma/backends/misc.py
#   inflating: sigma-master/tools/sigma/backends/mixins.py
#   inflating: sigma-master/tools/sigma/backends/netwitness-epl.py
#   inflating: sigma-master/tools/sigma/backends/netwitness.py
#   inflating: sigma-master/tools/sigma/backends/opensearch.py
#   inflating: sigma-master/tools/sigma/backends/powershell.py
#   inflating: sigma-master/tools/sigma/backends/qradar.py
#   inflating: sigma-master/tools/sigma/backends/qualys.py
#   inflating: sigma-master/tools/sigma/backends/splunk.py
#   inflating: sigma-master/tools/sigma/backends/splunkdm.py
#   inflating: sigma-master/tools/sigma/backends/sql.py
#   inflating: sigma-master/tools/sigma/backends/sqlite.py
#   inflating: sigma-master/tools/sigma/backends/stix.py
#   inflating: sigma-master/tools/sigma/backends/sumologic.py
#   inflating: sigma-master/tools/sigma/backends/sysmon.py
#   inflating: sigma-master/tools/sigma/backends/tools.py
#   inflating: sigma-master/tools/sigma/backends/uberagent.py
#    creating: sigma-master/tools/sigma/config/
#   inflating: sigma-master/tools/sigma/config/collection.py
#   inflating: sigma-master/tools/sigma/config/eventdict.py
#   inflating: sigma-master/tools/sigma/config/exceptions.py
#   inflating: sigma-master/tools/sigma/config/mapping.py
#   inflating: sigma-master/tools/sigma/configuration.py
#   inflating: sigma-master/tools/sigma/filter.py
#   inflating: sigma-master/tools/sigma/merge_sigma.py
#   inflating: sigma-master/tools/sigma/output.py
#    creating: sigma-master/tools/sigma/parser/
#   inflating: sigma-master/tools/sigma/parser/base.py
#   inflating: sigma-master/tools/sigma/parser/collection.py
#   inflating: sigma-master/tools/sigma/parser/condition.py
#   inflating: sigma-master/tools/sigma/parser/exceptions.py
#    creating: sigma-master/tools/sigma/parser/modifiers/
#   inflating: sigma-master/tools/sigma/parser/modifiers/__init__.py
#   inflating: sigma-master/tools/sigma/parser/modifiers/base.py
#   inflating: sigma-master/tools/sigma/parser/modifiers/discovery.py
#   inflating: sigma-master/tools/sigma/parser/modifiers/exceptions.py
#   inflating: sigma-master/tools/sigma/parser/modifiers/mixins.py
#   inflating: sigma-master/tools/sigma/parser/modifiers/transform.py
#   inflating: sigma-master/tools/sigma/parser/modifiers/type.py
#   inflating: sigma-master/tools/sigma/parser/rule.py
#   inflating: sigma-master/tools/sigma/sigma-similarity.py
#   inflating: sigma-master/tools/sigma/sigma-uuid.py
#   inflating: sigma-master/tools/sigma/sigma2attack.py
#   inflating: sigma-master/tools/sigma/sigma2genericsigma.py
#   inflating: sigma-master/tools/sigma/sigma2misp.py
#   inflating: sigma-master/tools/sigma/sigma_configurations_check.py
#   inflating: sigma-master/tools/sigma/sigma_similarity.py
#   inflating: sigma-master/tools/sigma/sigma_uuid.py
#   inflating: sigma-master/tools/sigma/sigmac.py
#   inflating: sigma-master/tools/sigma/tools.py
#   inflating: sigma-master/tools/sigma2attack
#   inflating: sigma-master/tools/sigma2misp
#   inflating: sigma-master/tools/sigma_configurations_check
#   inflating: sigma-master/tools/sigma_similarity
#   inflating: sigma-master/tools/sigma_uuid
#   inflating: sigma-master/tools/sigmac
#    creating: sigma-master/tools/tests/
#   inflating: sigma-master/tools/tests/test_backend_devo.py
#   inflating: sigma-master/tools/tests/test_backend_elasticsearch.py
#   inflating: sigma-master/tools/tests/test_backend_sql.py
#   inflating: sigma-master/tools/tests/test_backend_sqlite.py
#  extracting: sigma-master/tools/tests/test_parsing.py

# %% [markdown]
# ## Lecture des yaml et prise en compte

# %%
import os
import yaml
from pprint import pprint
def read_recursively():
  PATH=os.getcwd()+"/sigma-master/rules"
  result = [os.path.join(dp, f) for dp, dn, filenames in os.walk(PATH) for f in filenames if os.path.splitext(f)[1] == '.yml']
  return result
def get_yaml(yaml_file):
  with open(yaml_file, "r") as stream:
      try:
        pass
          #print(yaml.safe_load(stream))
      except yaml.YAMLError as exc:
          print(exc)

def get_logsources(dict_yml,yml_file):
  """Construction d'un logsourcen :
    #fieldName
    #value
    #document
  """
  res=[]
  dict_yml = dict_yml["logsource"]
  myres  = {"category" : "", "product" : "", "service" : "", "document" : yml_file}
  for key in dict_yml.keys():
    myres[key]=dict_yml[key]
    res.append(myres)

  return res

def get_selections(dict_yml, yml_file):
  """Construction d'une sélection :
    #fieldName
    #value
    #document
  """
  res=[]
  dict_yml = dict_yml["detection"]
  for pkey in dict_yml.keys():
    
    if pkey != "condition":
      if type(dict_yml[pkey])==dict :
        for key in dict_yml[pkey].keys():
          res.append({"fieldName" : key, "value" : str(dict_yml[pkey][key]), "document" : yml_file})

  return res

def get_all(all_yml):
  logsources=[]
  selections=[]
  for yml_file in all_yml :
      with open(yml_file, "r") as stream:
        dict_yml = yaml.safe_load(stream)
        logsources+=get_logsources(dict_yml,yml_file)
        selections+=get_selections(dict_yml,yml_file)
  return logsources, selections

# %% [markdown]
# ## Prise en compte sqlite

# %%
import sqlite3
from sqlite3 import Error


def create_connection(db_file):
    """ create a database connection to a SQLite database """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
    except Error as e:
        print(e)
    return conn

def create_table(conn, create_table_sql):
    """ create a table from the create_table_sql statement
    :param conn: Connection object
    :param create_table_sql: a CREATE TABLE statement
    :return:
    """
    try:
        c = conn.cursor()
        c.execute(create_table_sql)
    except Error as e:
        print(e)

def create_selection(conn, selection):
    """
    Create a new task
    :param conn:
    :param task:
    :return:
    """

    sql = ''' INSERT INTO selections(fieldName, value,document)
              VALUES(?,?,?) '''
    cur = conn.cursor()
    cur.execute(sql, selection)
    conn.commit()

    return cur.lastrowid

def create_logsource(conn, logsource):
    """
    Create a new task
    :param conn:
    :param task:
    :return:
    """

    sql = ''' INSERT INTO logsources(category, product,service, document)
              VALUES(?,?,?,?) '''
    cur = conn.cursor()
    cur.execute(sql, logsource)
    conn.commit()

    return cur.lastrowid

def select_all_selections(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    cur.execute("SELECT * FROM selections")

    rows = cur.fetchall()

    for row in rows:
        print(row)

def exec_selection(conn, instr):
  cur = conn.cursor()
  cur.execute(instr)

  rows = cur.fetchall()


  return rows

def select_selections_by_fieldName(conn, fieldName):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    cur.execute("SELECT * FROM selections WHERE fieldName=?",(fieldName,))

    rows = cur.fetchall()

    for row in rows:
        print(row)

def add_data(conn, logsources, selections):
  # create logsources and selections tables
  for logsrc in logsources :
    create_logsource(conn, [logsrc["category"], logsrc["product"], logsrc["service"], logsrc["document"]])
  for selection in selections:
    create_selection(conn, [selection["fieldName"], selection["value"], selection["document"]])

def create_db():
  database = r"pythonsqlite.db"

  import os
  if os.path.isfile(database):
    os.remove(database)

  sql_create_logsources_table = """ CREATE TABLE IF NOT EXISTS logsources (
                                      id integer PRIMARY KEY,
                                      category text NOT NULL,
                                      product text,
                                      service text,
                                      document text
                                  ); """

  sql_create_selections_table = """ CREATE TABLE IF NOT EXISTS selections (
                                      id integer PRIMARY KEY,
                                      fieldName text NOT NULL,
                                      value text,
                                      document text
                                  ); """


  
  # create a database connection
  conn = create_connection(database)
  create_table(conn, sql_create_logsources_table)
  create_table(conn, sql_create_selections_table)
  return conn

# %%
all_yml = read_recursively()
logsources, selections  = get_all(all_yml)
print(logsources[0], selections[0])
conn = create_db()
add_data(conn, logsources, selections)
# Out:
# {'category': 'authentication', 'product': '', 'service': '', 'document': '/content/sigma-master/rules/generic/generic_brute_force.yml'} {'fieldName': 'action', 'value': 'failure', 'document': '/content/sigma-master/rules/generic/generic_brute_force.yml'}

# %% [markdown]
# ## See result of "eventID"

# %%
select_selections_by_fieldName(conn,"EventID")
# Out:
# (263, 'EventID', '[12, 13]', '/content/sigma-master/rules/windows/malware/registry_event_mal_azorult.yml')
# (387, 'EventID', '[19, 20, 21]', '/content/sigma-master/rules/windows/wmi_event/sysmon_wmi_event_subscription.yml')
# (563, 'EventID', '[6, 8]', '/content/sigma-master/rules/windows/other/win_exchange_cve_2021_42321.yml')
# (564, 'EventID', '[1006, 1116, 1015, 1117]', '/content/sigma-master/rules/windows/other/win_defender_threat.yml')
# (565, 'EventID', '5861', '/content/sigma-master/rules/windows/other/win_wmi_persistence.yml')
# (566, 'EventID', '5859', '/content/sigma-master/rules/windows/other/win_wmi_persistence.yml')
# (567, 'EventID', '[5001, 5010, 5012, 5101]', '/content/sigma-master/rules/windows/other/win_defender_disabled.yml')
# (568, 'EventID', '4662', '/content/sigma-master/rules/windows/other/win_security_wmi_persistence.yml')
# (571, 'EventID', '1121', '/content/sigma-master/rules/windows/other/win_defender_psexec_wmi_asr.yml')
# (573, 'EventID', '7045', '/content/sigma-master/rules/windows/other/win_tool_psexec.yml')
# (576, 'EventID', '7036', '/content/sigma-master/rules/windows/other/win_tool_psexec.yml')
# (578, 'EventID', '1116', '/content/sigma-master/rules/windows/other/win_defender_amsi_trigger.yml')
# (580, 'EventID', '[4657, 4656, 4660, 4663]', '/content/sigma-master/rules/windows/other/win_defender_bypass.yml')
# (582, 'EventID', '4674', '/content/sigma-master/rules/windows/other/win_lateral_movement_condrv.yml')
# (586, 'EventID', '1013', '/content/sigma-master/rules/windows/other/win_defender_history_delete.yml')
# (588, 'EventID', '106', '/content/sigma-master/rules/windows/other/win_rare_schtask_creation.yml')
# (589, 'EventID', "['5805', '5723']", '/content/sigma-master/rules/windows/other/win_possible_zerologon_exploitation_using_wellknown_tools.yml')
# (590, 'EventID', '4697', '/content/sigma-master/rules/windows/other/win_pcap_drivers.yml')
# (592, 'EventID', '30', '/content/sigma-master/rules/windows/other/win_ldap_recon.yml')
# (594, 'EventID', '30', '/content/sigma-master/rules/windows/other/win_ldap_recon.yml')
# (596, 'EventID', '30', '/content/sigma-master/rules/windows/other/win_ldap_recon.yml')
# (598, 'EventID', '6', '/content/sigma-master/rules/windows/other/win_exchange_transportagent_failed.yml')
# (599, 'EventID', '7036', '/content/sigma-master/rules/windows/other/win_system_defender_disabled.yml')
# (603, 'EventID', '5007', '/content/sigma-master/rules/windows/other/win_defender_exclusions.yml')
# (605, 'EventID', '[5013]', '/content/sigma-master/rules/windows/other/win_defender_tamper_protection_trigger.yml')
# (2270, 'EventID', '4657', '/content/sigma-master/rules/windows/builtin/win_etw_modification.yml')
# (2274, 'EventID', '5145', '/content/sigma-master/rules/windows/builtin/win_gpo_scheduledtasks.yml')
# (2278, 'EventID', '7045', '/content/sigma-master/rules/windows/builtin/win_hack_smbexec.yml')
# (2281, 'EventID', '[5038, 6281]', '/content/sigma-master/rules/windows/builtin/win_susp_codeintegrity_check_failure.yml')
# (2282, 'EventID', '7045', '/content/sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_use_rundll32_services.yml')
# (2286, 'EventID', '[529, 4625]', '/content/sigma-master/rules/windows/builtin/win_susp_failed_logons_single_source.yml')
# (2289, 'EventID', '4648', '/content/sigma-master/rules/windows/builtin/win_susp_failed_logons_explicit_credentials.yml')
# (2290, 'EventID', '4776', '/content/sigma-master/rules/windows/builtin/win_susp_failed_logons_single_source2.yml')
# (2293, 'EventID', '[40300, 40301, 40302]', '/content/sigma-master/rules/windows/builtin/win_hybridconnectionmgr_svc_running.yml')
# (2294, 'EventID', '[4625, 4624]', '/content/sigma-master/rules/windows/builtin/win_metasploit_authentication.yml')
# (2299, 'EventID', '4776', '/content/sigma-master/rules/windows/builtin/win_metasploit_authentication.yml')
# (2301, 'EventID', '[4656, 4658, 4660, 4663]', '/content/sigma-master/rules/windows/builtin/win_mal_wceaux_dll.yml')
# (2304, 'EventID', '1000', '/content/sigma-master/rules/windows/builtin/win_susp_msmpeng_crash.yml')
# (2306, 'EventID', '1001', '/content/sigma-master/rules/windows/builtin/win_susp_msmpeng_crash.yml')
# (2307, 'EventID', '5145', '/content/sigma-master/rules/windows/builtin/win_impacket_psexec.yml')
# (2310, 'EventID', '7045', '/content/sigma-master/rules/windows/builtin/win_powershell_script_installed_as_service.yml')
# (2312, 'EventID', '4825', '/content/sigma-master/rules/windows/builtin/win_not_allowed_rdp_access.yml')
# (2313, 'EventID', '4698', '/content/sigma-master/rules/windows/builtin/win_rare_schtasks_creations.yml')
# (2314, 'EventID', '5145', '/content/sigma-master/rules/windows/builtin/win_lm_namedpipe.yml')
# (2316, 'EventID', '5145', '/content/sigma-master/rules/windows/builtin/win_lm_namedpipe.yml')
# (2319, 'EventID', '4898', '/content/sigma-master/rules/windows/builtin/win_adcs_certificate_template_configuration_vulnerability.yml')
# (2321, 'EventID', '4899', '/content/sigma-master/rules/windows/builtin/win_adcs_certificate_template_configuration_vulnerability.yml')
# (2323, 'EventID', '4769', '/content/sigma-master/rules/windows/builtin/win_susp_rc4_kerberos.yml')
# (2327, 'EventID', '4776', '/content/sigma-master/rules/windows/builtin/win_susp_failed_logons_single_source_ntlm.yml')
# (2330, 'EventID', '7045', '/content/sigma-master/rules/windows/builtin/win_invoke_obfuscation_clip_services.yml')
# (2332, 'EventID', '4697', '/content/sigma-master/rules/windows/builtin/win_security_tap_driver_installation.yml')
# (2334, 'EventID', '7045', '/content/sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_stdin_services.yml')
# (2336, 'EventID', '5145', '/content/sigma-master/rules/windows/builtin/win_petitpotam_network_share.yml')
# (2341, 'EventID', '4719', '/content/sigma-master/rules/windows/builtin/win_disable_event_logging.yml')
# (2343, 'EventID', '5140', '/content/sigma-master/rules/windows/builtin/win_admin_share_access.yml')
# (2346, 'EventID', '5145', '/content/sigma-master/rules/windows/builtin/win_dcom_iertutil_dll_hijack.yml')
# (2349, 'EventID', '4732', '/content/sigma-master/rules/windows/builtin/win_user_added_to_local_administrators.yml')
# (2353, 'EventID', '4697', '/content/sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_use_clip_services_security.yml')
# (2355, 'EventID', '4706', '/content/sigma-master/rules/windows/builtin/win_susp_add_domain_trust.yml')
# (2356, 'EventID', '7045', '/content/sigma-master/rules/windows/builtin/win_moriya_rootkit.yml')
# (2358, 'EventID', '4624', '/content/sigma-master/rules/windows/builtin/win_susp_wmi_login.yml')
# (2360, 'EventID', '5829', '/content/sigma-master/rules/windows/builtin/win_vul_cve_2020_1472.yml')
# (2361, 'EventID', '[4656, 4663, 4658]', '/content/sigma-master/rules/windows/builtin/win_susp_sdelete.yml')
# (2363, 'EventID', '4697', '/content/sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_var_services_security.yml')
# (2365, 'EventID', '4768', '/content/sigma-master/rules/windows/builtin/win_susp_failed_logons_single_source_kerberos2.yml')
# (2368, 'EventID', '4697', '/content/sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_compress_services_security.yml')
# (2370, 'EventID', '5145', '/content/sigma-master/rules/windows/builtin/win_transferring_files_with_credential_data_via_network_shares.yml')
# (2372, 'EventID', '4624', '/content/sigma-master/rules/windows/builtin/win_susp_rottenpotato.yml')
# (2377, 'EventID', '4698', '/content/sigma-master/rules/windows/builtin/win_apt_chafer_mar18_security.yml')
# (2379, 'EventID', '7045', '/content/sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_use_clip_services.yml')
# (2381, 'EventID', '4738', '/content/sigma-master/rules/windows/builtin/win_alert_enable_weak_encryption.yml')
# (2388, 'EventID', '4697', '/content/sigma-master/rules/windows/builtin/win_invoke_obfuscation_obfuscated_iex_services_security.yml')
# (2389, 'EventID', '[150, 770]', '/content/sigma-master/rules/windows/builtin/win_susp_dns_config.yml')
# (2391, 'EventID', '98', '/content/sigma-master/rules/windows/builtin/win_volume_shadow_copy_mount.yml')
# (2393, 'EventID', '4704', '/content/sigma-master/rules/windows/builtin/win_alert_active_directory_user_control.yml')
# (2395, 'EventID', '4657', '/content/sigma-master/rules/windows/builtin/win_sysmon_channel_reference_deletion.yml')
# (2399, 'EventID', '4663', '/content/sigma-master/rules/windows/builtin/win_sysmon_channel_reference_deletion.yml')
# (2402, 'EventID', '5145', '/content/sigma-master/rules/windows/builtin/win_smb_file_creation_admin_shares.yml')
# (2406, 'EventID', '8002', '/content/sigma-master/rules/windows/builtin/win_susp_ntlm_auth.yml')
# (2408, 'EventID', '[2003, 2100, 2102]', '/content/sigma-master/rules/windows/builtin/win_usb_device_plugged.yml')
# (2409, 'EventID', '4', '/content/sigma-master/rules/windows/builtin/win_vul_cve_2020_0688.yml')
# (2412, 'EventID', '104', '/content/sigma-master/rules/windows/builtin/win_system_susp_eventlog_cleared.yml')
# (2414, 'EventID', '4656', '/content/sigma-master/rules/windows/builtin/win_sam_registry_hive_handle_request.yml')
# (2417, 'EventID', '316', '/content/sigma-master/rules/windows/builtin/win_exploit_cve_2021_1675_printspooler_operational.yml')
# (2419, 'EventID', '4697', '/content/sigma-master/rules/windows/builtin/win_security_meterpreter_or_cobaltstrike_getsystem_service_install.yml')
# (2420, 'EventID', '[56, 50]', '/content/sigma-master/rules/windows/builtin/win_rdp_potential_cve_2019_0708.yml')
# (2422, 'EventID', '4662', '/content/sigma-master/rules/windows/builtin/win_dcsync.yml')
# (2427, 'EventID', '4697', '/content/sigma-master/rules/windows/builtin/win_hybridconnectionmgr_svc_installation.yml')
# (2430, 'EventID', '[4624, 4625]', '/content/sigma-master/rules/windows/builtin/win_pass_the_hash.yml')
# (2436, 'EventID', '4697', '/content/sigma-master/rules/windows/builtin/win_security_mal_service_installs.yml')
# (2438, 'EventID', '7045', '/content/sigma-master/rules/windows/builtin/win_apt_carbonpaper_turla.yml')
# (2440, 'EventID', '1121', '/content/sigma-master/rules/windows/builtin/win_alert_lsass_access.yml')
# (2442, 'EventID', '5145', '/content/sigma-master/rules/windows/builtin/win_susp_psexec.yml')
# (2445, 'EventID', '5145', '/content/sigma-master/rules/windows/builtin/win_susp_psexec.yml')
# (2448, 'EventID', '4662', '/content/sigma-master/rules/windows/builtin/win_ad_replication_non_machine_account.yml')
# (2451, 'EventID', '31017', '/content/sigma-master/rules/windows/builtin/win_susp_failed_guest_logon.yml')
# (2455, 'EventID', '4699', '/content/sigma-master/rules/windows/builtin/win_scheduled_task_deletion.yml')
# (2456, 'EventID', '4662', '/content/sigma-master/rules/windows/builtin/win_ad_object_writedac_access.yml')
# (2460, 'EventID', '4776', '/content/sigma-master/rules/windows/builtin/win_alert_ruler.yml')
# (2462, 'EventID', '[4624, 4625]', '/content/sigma-master/rules/windows/builtin/win_alert_ruler.yml')
# (2464, 'EventID', '4720', '/content/sigma-master/rules/windows/builtin/win_user_creation.yml')
# (2465, 'EventID', '4904', '/content/sigma-master/rules/windows/builtin/win_vssaudit_secevent_source_registration.yml')
# (2467, 'EventID', '4905', '/content/sigma-master/rules/windows/builtin/win_vssaudit_secevent_source_registration.yml')
# (2469, 'EventID', '5145', '/content/sigma-master/rules/windows/builtin/win_susp_raccess_sensitive_fext.yml')
# (2471, 'EventID', '4697', '/content/sigma-master/rules/windows/builtin/win_security_powershell_script_installed_as_service.yml')
# (2473, 'EventID', '5145', '/content/sigma-master/rules/windows/builtin/win_wmiprvse_wbemcomn_dll_hijack.yml')
# (2476, 'EventID', '4697', '/content/sigma-master/rules/windows/builtin/win_invoke_obfuscation_var_services_security.yml')
# (2480, 'EventID', '[4720, 4781]', '/content/sigma-master/rules/windows/builtin/win_new_or_renamed_user_account_with_dollar_sign.yml')
# (2482, 'EventID', '7045', '/content/sigma-master/rules/windows/builtin/win_invoke_obfuscation_stdin_services.yml')
# (2485, 'EventID', '55', '/content/sigma-master/rules/windows/builtin/win_ntfs_vuln_exploit.yml')
# (2488, 'EventID', '7045', '/content/sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_compress_services.yml')
# (2490, 'EventID', '4720', '/content/sigma-master/rules/windows/builtin/win_susp_local_anon_logon_created.yml')
# (2492, 'EventID', '7045', '/content/sigma-master/rules/windows/builtin/win_mal_creddumper.yml')
# (2494, 'EventID', '7045', '/content/sigma-master/rules/windows/builtin/win_apt_chafer_mar18_system.yml')
# (2496, 'EventID', '5145', '/content/sigma-master/rules/windows/builtin/win_susp_samr_pwset.yml')
# (2498, 'EventID', '4738', '/content/sigma-master/rules/windows/builtin/win_susp_samr_pwset.yml')
# (2500, 'EventID', '5145', '/content/sigma-master/rules/windows/builtin/win_svcctl_remote_service.yml')
# (2504, 'EventID', '4674', '/content/sigma-master/rules/windows/builtin/win_scm_database_privileged_operation.yml')
# (2509, 'EventID', '[528, 529, 4624, 4625]', '/content/sigma-master/rules/windows/builtin/win_susp_interactive_logons.yml')
# (2514, 'EventID', '7045', '/content/sigma-master/rules/windows/builtin/win_susp_proceshacker.yml')
# (2517, 'EventID', '1102', '/content/sigma-master/rules/windows/builtin/win_event_log_cleared.yml')
# (2519, 'EventID', '4656', '/content/sigma-master/rules/windows/builtin/win_susp_lsass_dump.yml')
# (2523, 'EventID', '4657', '/content/sigma-master/rules/windows/builtin/win_net_ntlm_downgrade.yml')
# (2526, 'EventID', '4742', '/content/sigma-master/rules/windows/builtin/win_possible_dc_shadow.yml')
# (2528, 'EventID', '5136', '/content/sigma-master/rules/windows/builtin/win_possible_dc_shadow.yml')
# (2531, 'EventID', '4692', '/content/sigma-master/rules/windows/builtin/win_dpapi_domain_masterkey_backup_attempt.yml')
# (2532, 'EventID', '4697', '/content/sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_rundll_services_security.yml')
# (2534, 'EventID', '7045', '/content/sigma-master/rules/windows/builtin/win_cobaltstrike_service_installs.yml')
# (2539, 'EventID', '4720', '/content/sigma-master/rules/windows/builtin/win_hidden_user_creation.yml')
# (2541, 'EventID', '4661', '/content/sigma-master/rules/windows/builtin/win_account_discovery.yml')
# (2543, 'EventID', '4611', '/content/sigma-master/rules/windows/builtin/win_register_new_logon_process_by_rubeus.yml')
# (2545, 'EventID', '7045', '/content/sigma-master/rules/windows/builtin/win_rare_service_installs.yml')
# (2546, 'EventID', '4661', '/content/sigma-master/rules/windows/builtin/win_susp_net_recon_activity.yml')
# (2551, 'EventID', '4663', '/content/sigma-master/rules/windows/builtin/win_susp_multiple_files_renamed_or_deleted.yml')
# (2555, 'EventID', '[4625, 4776]', '/content/sigma-master/rules/windows/builtin/win_susp_failed_logon_reasons.yml')
# (2558, 'EventID', '7045', '/content/sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_use_mshta_services.yml')
# (2560, 'EventID', '4104', '/content/sigma-master/rules/windows/builtin/win_root_certificate_installed.yml')
# (2562, 'EventID', '4104', '/content/sigma-master/rules/windows/builtin/win_root_certificate_installed.yml')
# (2564, 'EventID', '4656', '/content/sigma-master/rules/windows/builtin/win_scm_database_handle_failure.yml')
# (2568, 'EventID', '4771', '/content/sigma-master/rules/windows/builtin/win_susp_failed_logons_single_source_kerberos.yml')
# (2571, 'EventID', '5145', '/content/sigma-master/rules/windows/builtin/win_exploit_cve_2021_1675_printspooler_security.yml')
# (2576, 'EventID', '[808, 4909]', '/content/sigma-master/rules/windows/builtin/win_exploit_cve_2021_1675_printspooler.yml')
# (2578, 'EventID', '4616', '/content/sigma-master/rules/windows/builtin/win_susp_time_modification.yml')
# (2583, 'EventID', '[4663, 4656]', '/content/sigma-master/rules/windows/builtin/win_lsass_access_non_system_account.yml')
# (2589, 'EventID', '5156', '/content/sigma-master/rules/windows/builtin/win_suspicious_outbound_kerberos_connection.yml')
# (2592, 'EventID', '16', '/content/sigma-master/rules/windows/builtin/win_quarkspwdump_clearing_hive_access_history.yml')
# (2595, 'EventID', '5136', '/content/sigma-master/rules/windows/builtin/win_susp_ldap_dataexchange.yml')
# (2598, 'EventID', '4624', '/content/sigma-master/rules/windows/builtin/win_overpass_the_hash.yml')
# (2602, 'EventID', '4662', '/content/sigma-master/rules/windows/builtin/win_dpapi_domain_backupkey_extraction.yml')
# (2606, 'EventID', '4697', '/content/sigma-master/rules/windows/builtin/win_security_metasploit_or_impacket_smb_psexec_service_install.yml')
# (2612, 'EventID', '5156', '/content/sigma-master/rules/windows/builtin/win_remote_powershell_session.yml')
# (2615, 'EventID', '7045', '/content/sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_rundll_services.yml')
# (2617, 'EventID', '4701', '/content/sigma-master/rules/windows/builtin/win_apt_slingshot.yml')
# (2619, 'EventID', '1033', '/content/sigma-master/rules/windows/builtin/win_vul_cve_2021_41379.yml')
# (2621, 'EventID', '4662', '/content/sigma-master/rules/windows/builtin/win_ad_user_enumeration.yml')
# (2623, 'EventID', '4697', '/content/sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_use_rundll32_services_security.yml')
# (2625, 'EventID', '[517, 1102]', '/content/sigma-master/rules/windows/builtin/win_susp_eventlog_cleared.yml')
# (2627, 'EventID', '524', '/content/sigma-master/rules/windows/builtin/win_susp_backup_delete.yml')
# (2629, 'EventID', '4625', '/content/sigma-master/rules/windows/builtin/win_susp_failed_logon_source.yml')
# (2632, 'EventID', '4663', '/content/sigma-master/rules/windows/builtin/win_iso_mount.yml')
# (2637, 'EventID', '4794', '/content/sigma-master/rules/windows/builtin/win_susp_dsrm_password_change.yml')
# (2638, 'EventID', '4697', '/content/sigma-master/rules/windows/builtin/win_security_mal_creddumper.yml')
# (2640, 'EventID', '7045', '/content/sigma-master/rules/windows/builtin/win_invoke_obfuscation_obfuscated_iex_services.yml')
# (2644, 'EventID', '4697', '/content/sigma-master/rules/windows/builtin/win_invoke_obfuscation_clip_services_security.yml')
# (2648, 'EventID', '7045', '/content/sigma-master/rules/windows/builtin/win_invoke_obfuscation_var_services.yml')
# (2650, 'EventID', '7045', '/content/sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_var_services.yml')
# (2652, 'EventID', '8001', '/content/sigma-master/rules/windows/builtin/win_susp_ntlm_rdp.yml')
# (2654, 'EventID', '4768', '/content/sigma-master/rules/windows/builtin/win_susp_failed_logons_single_source_kerberos3.yml')
# (2657, 'EventID', '5156', '/content/sigma-master/rules/windows/builtin/win_rdp_reverse_tunnel.yml')
# (2662, 'EventID', '4697', '/content/sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_stdin_services_security.yml')
# (2664, 'EventID', '[675, 4768, 4769, 4771]', '/content/sigma-master/rules/windows/builtin/win_susp_kerberos_manipulation.yml')
# (2666, 'EventID', '5136', '/content/sigma-master/rules/windows/builtin/win_account_backdoor_dcsync_rights.yml')
# (2669, 'EventID', '4768', '/content/sigma-master/rules/windows/builtin/win_petitpotam_susp_tgt_request.yml')
# (2674, 'EventID', '1033', '/content/sigma-master/rules/windows/builtin/win_software_atera_rmm_agent_install.yml')
# (2677, 'EventID', '257', '/content/sigma-master/rules/windows/builtin/win_apt_gallium.yml')
# (2679, 'EventID', '4673', '/content/sigma-master/rules/windows/builtin/win_user_couldnt_call_privileged_service_lsaregisterlogonprocess.yml')
# (2682, 'EventID', '[1031, 1032, 1034]', '/content/sigma-master/rules/windows/builtin/win_susp_dhcp_config_failed.yml')
# (2684, 'EventID', '7045', '/content/sigma-master/rules/windows/builtin/win_apt_turla_service_png.yml')
# (2686, 'EventID', '6416', '/content/sigma-master/rules/windows/builtin/win_external_device.yml')
# (2689, 'EventID', '4625', '/content/sigma-master/rules/windows/builtin/win_susp_failed_remote_logons_single_source.yml')
# (2692, 'EventID', '4624', '/content/sigma-master/rules/windows/builtin/win_scrcons_remote_wmi_scripteventconsumer.yml')
# (2696, 'EventID', '4697', '/content/sigma-master/rules/windows/builtin/win_invoke_obfuscation_via_use_mshta_services_security.yml')
# (2698, 'EventID', '5145', '/content/sigma-master/rules/windows/builtin/win_remote_registry_management_using_reg_utility.yml')
# (2701, 'EventID', '5145', '/content/sigma-master/rules/windows/builtin/win_impacket_secretdump.yml')
# (2704, 'EventID', '4625', '/content/sigma-master/rules/windows/builtin/win_susp_failed_logons_single_process.yml')
# (2708, 'EventID', '7045', '/content/sigma-master/rules/windows/builtin/win_tap_driver_installation.yml')
# (2710, 'EventID', '4624', '/content/sigma-master/rules/windows/builtin/win_admin_rdp_login.yml')
# (2714, 'EventID', '4742', '/content/sigma-master/rules/windows/builtin/win_privesc_cve_2020_1472.yml')
# (2718, 'EventID', '4656', '/content/sigma-master/rules/windows/builtin/win_susp_lsass_dump_generic.yml')
# (2721, 'EventID', '4663', '/content/sigma-master/rules/windows/builtin/win_susp_lsass_dump_generic.yml')
# (2727, 'EventID', '16', '/content/sigma-master/rules/windows/builtin/win_susp_sam_dump.yml')
# (2728, 'EventID', '[8004, 8007]', '/content/sigma-master/rules/windows/builtin/win_applocker_file_was_not_allowed_to_run.yml')
# (2729, 'EventID', '[4765, 4766]', '/content/sigma-master/rules/windows/builtin/win_susp_add_sid_history.yml')
# (2730, 'EventID', '4738', '/content/sigma-master/rules/windows/builtin/win_susp_add_sid_history.yml')
# (2733, 'EventID', '[4656, 4663]', '/content/sigma-master/rules/windows/builtin/win_aadhealth_mon_agent_regkey_access.yml')
# (2737, 'EventID', '4624', '/content/sigma-master/rules/windows/builtin/win_rdp_localhost_login.yml')
# (2740, 'EventID', '4648', '/content/sigma-master/rules/windows/builtin/win_susp_logon_explicit_credentials.yml')
# (2743, 'EventID', '7045', '/content/sigma-master/rules/windows/builtin/win_meterpreter_or_cobaltstrike_getsystem_service_installation.yml')
# (2744, 'EventID', '4689', '/content/sigma-master/rules/windows/builtin/win_lolbas_execution_of_nltest.yml')
# (2747, 'EventID', '1033', '/content/sigma-master/rules/windows/builtin/win_susp_dhcp_config.yml')
# (2749, 'EventID', '4776', '/content/sigma-master/rules/windows/builtin/win_susp_failed_logons_single_source_ntlm2.yml')
# (2752, 'EventID', '4738', '/content/sigma-master/rules/windows/builtin/win_alert_ad_user_backdoors.yml')
# (2755, 'EventID', '5136', '/content/sigma-master/rules/windows/builtin/win_alert_ad_user_backdoors.yml')
# (2757, 'EventID', '5136', '/content/sigma-master/rules/windows/builtin/win_alert_ad_user_backdoors.yml')
# (2760, 'EventID', '5136', '/content/sigma-master/rules/windows/builtin/win_alert_ad_user_backdoors.yml')
# (2762, 'EventID', '5145', '/content/sigma-master/rules/windows/builtin/win_atsvc_task.yml')
# (2766, 'EventID', '[4657, 4656, 4663]', '/content/sigma-master/rules/windows/builtin/win_camera_microphone_access.yml')
# (2769, 'EventID', '[4656, 4663]', '/content/sigma-master/rules/windows/builtin/win_syskey_registry_access.yml')
# (2772, 'EventID', '4625', '/content/sigma-master/rules/windows/builtin/win_rdp_bluekeep_poc_scanner.yml')
# (2774, 'EventID', '5145', '/content/sigma-master/rules/windows/builtin/win_protected_storage_service_access.yml')
# (2777, 'EventID', '4673', '/content/sigma-master/rules/windows/builtin/win_user_driver_loaded.yml')
# (2781, 'EventID', '4799', '/content/sigma-master/rules/windows/builtin/win_apt_wocao.yml')
# (2784, 'EventID', '7045', '/content/sigma-master/rules/windows/builtin/win_apt_stonedrill.yml')
# (2787, 'EventID', '5156', '/content/sigma-master/rules/windows/builtin/win_global_catalog_enumeration.yml')
# (2789, 'EventID', '4898', '/content/sigma-master/rules/windows/builtin/win_adcs_certificate_template_configuration_vulnerability_eku.yml')
# (2792, 'EventID', '4899', '/content/sigma-master/rules/windows/builtin/win_adcs_certificate_template_configuration_vulnerability_eku.yml')
# (2795, 'EventID', '4697', '/content/sigma-master/rules/windows/builtin/win_security_cobaltstrike_service_installs.yml')
# (2801, 'EventID', '[4656, 4663]', '/content/sigma-master/rules/windows/builtin/win_aadhealth_svc_agent_regkey_access.yml')
# (2805, 'EventID', '5145', '/content/sigma-master/rules/windows/builtin/win_dce_rpc_smb_spoolss_named_pipe.yml')
# (2808, 'EventID', '4697', '/content/sigma-master/rules/windows/builtin/win_invoke_obfuscation_stdin_services_security.yml')
# (2830, 'EventID', '11', '/content/sigma-master/rules/windows/sysmon/sysmon_dcom_iertutil_dll_hijack.yml')
# (2833, 'EventID', '7', '/content/sigma-master/rules/windows/sysmon/sysmon_dcom_iertutil_dll_hijack.yml')
# (2836, 'EventID', '[8, 10]', '/content/sigma-master/rules/windows/sysmon/sysmon_accessing_winapi_in_powershell_credentials_dumping.yml')
# (2844, 'EventID', '[4728, 4729, 4730, 633, 632, 634]', '/content/sigma-master/rules/compliance/group_modification_logging.yml')
# (2846, 'EventID', '[4800]', '/content/sigma-master/rules/compliance/workstation_was_locked.yml')

# %% [markdown]
# ## Search term

# %%
def search_docs_by_term_in_column(conn, table, column,search_str ):
  instr = f"SELECT {column}, document FROM {table} WHERE {column} LIKE '%{search_str}%'"
  res  = exec_selection(conn, instr)
  return res

def search_docs_by_fixed_table(conn, table_fixed, column_fixed, search_str_fixed, table, column, search_str):
  instr_pre = f"SELECT document FROM {table_fixed} WHERE {column_fixed} LIKE '%{search_str_fixed}%'"
  instr = f"SELECT document FROM {table} WHERE {column} LIKE '%{search_str}%' AND document IN ({instr_pre})"
  res  = exec_selection(conn, instr)
  return [a[0] for a in res]
print(search_docs_by_term_in_column(conn, "logsources","product", "a" ))
print("---------------------")
print(search_docs_by_fixed_table(conn, "logsources", "product", "win", "selections", "fieldName", "event"))
# Out:
# [('django', '/content/sigma-master/rules/application/appframework_django_exceptions.yml'), ('django', '/content/sigma-master/rules/application/appframework_django_exceptions.yml'), ('ruby_on_rails', '/content/sigma-master/rules/application/appframework_ruby_on_rails_exceptions.yml'), ('ruby_on_rails', '/content/sigma-master/rules/application/appframework_ruby_on_rails_exceptions.yml'), ('zoho_manageengine', '/content/sigma-master/rules/web/web_cve_2021_40539_manageengine_adselfservice_exploit.yml'), ('zoho_manageengine', '/content/sigma-master/rules/web/web_cve_2021_40539_manageengine_adselfservice_exploit.yml'), ('zoho_manageengine', '/content/sigma-master/rules/web/web_cve_2021_40539_manageengine_adselfservice_exploit.yml'), ('apache', '/content/sigma-master/rules/web/web_nginx_core_dump.yml'), ('apache', '/content/sigma-master/rules/web/web_apache_segfault.yml'), ('apache', '/content/sigma-master/rules/web/web_apache_threading_error.yml'), ('antivirus', '/content/sigma-master/rules/windows/malware/av_printernightmare_cve_2021_34527.yml'), ('antivirus', '/content/sigma-master/rules/windows/malware/av_exploiting.yml'), ('antivirus', '/content/sigma-master/rules/windows/malware/av_password_dumper.yml'), ('antivirus', '/content/sigma-master/rules/windows/malware/av_relevant_files.yml'), ('antivirus', '/content/sigma-master/rules/windows/malware/av_webshell.yml'), ('antivirus', '/content/sigma-master/rules/windows/malware/av_hacktool.yml'), ('qualys', '/content/sigma-master/rules/compliance/host_without_firewall.yml'), ('qualys', '/content/sigma-master/rules/compliance/default_credentials_usage.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_kubernetes_pods_deleted.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_kubernetes_pods_deleted.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_kubernetes_events_deleted.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_kubernetes_events_deleted.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_vpn_connection_modified_or_deleted.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_vpn_connection_modified_or_deleted.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_suppression_rule_created.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_suppression_rule_created.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_new_cloudshell_created.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_new_cloudshell_created.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_federation_modified.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_federation_modified.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_aadhybridhealth_adfs_new_server.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_aadhybridhealth_adfs_new_server.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_kubernetes_cluster_created_or_deleted.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_kubernetes_cluster_created_or_deleted.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_account_lockout.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_account_lockout.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_keyvault_key_modified_or_deleted.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_keyvault_key_modified_or_deleted.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_granting_permission_detection.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_granting_permission_detection.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_keyvault_modified_or_deleted.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_keyvault_modified_or_deleted.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_kubernetes_secret_or_config_object_access.yml'), ('azure', '/content/sigma-master/rules/cloud/azure/azure_kubernetes_s ...
# ---------------------
# ['/content/sigma-master/rules/windows/malware/registry_event_mal_azorult.yml', '/content/sigma-master/rules/windows/wmi_event/sysmon_wmi_event_subscription.yml', '/content/sigma-master/rules/windows/other/win_exchange_cve_2021_42321.yml', '/content/sigma-master/rules/windows/other/win_defender_threat.yml', '/content/sigma-master/rules/windows/other/win_wmi_persistence.yml', '/content/sigma-master/rules/windows/other/win_wmi_persistence.yml', '/content/sigma-master/rules/windows/other/win_defender_disabled.yml', '/content/sigma-master/rules/windows/other/win_security_wmi_persistence.yml', '/content/sigma-master/rules/windows/other/win_defender_psexec_wmi_asr.yml', '/content/sigma-master/rules/windows/other/win_tool_psexec.yml', '/content/sigma-master/rules/windows/other/win_tool_psexec.yml', '/content/sigma-master/rules/windows/other/win_defender_amsi_trigger.yml', '/content/sigma-master/rules/windows/other/win_defender_bypass.yml', '/content/sigma-master/rules/windows/other/win_lateral_movement_condrv.yml', '/content/sigma-master/rules/windows/other/win_defender_history_delete.yml', '/content/sigma-master/rules/windows/other/win_defender_history_delete.yml', '/content/sigma-master/rules/windows/other/win_rare_schtask_creation.yml', '/content/sigma-master/rules/windows/other/win_possible_zerologon_exploitation_using_wellknown_tools.yml', '/content/sigma-master/rules/windows/other/win_pcap_drivers.yml', '/content/sigma-master/rules/windows/other/win_ldap_recon.yml', '/content/sigma-master/rules/windows/other/win_ldap_recon.yml', '/content/sigma-master/rules/windows/other/win_ldap_recon.yml', '/content/sigma-master/rules/windows/other/win_exchange_transportagent_failed.yml', '/content/sigma-master/rules/windows/other/win_system_defender_disabled.yml', '/content/sigma-master/rules/windows/other/win_defender_exclusions.yml', '/content/sigma-master/rules/windows/other/win_defender_tamper_protection_trigger.yml', '/content/sigma-master/rules/windows/registry_event/sysmon_registry_persistence_key_linking.yml', '/content/sigma-master/rules/windows/registry_event/win_registry_file_association_exefile.yml', '/content/sigma-master/rules/windows/registry_event/registry_event_defender_exclusions.yml', '/content/sigma-master/rules/windows/registry_event/sysmon_disabled_exploit_guard_network_protection_on_microsoft_defender.yml', '/content/sigma-master/rules/windows/registry_event/sysmon_office_vsto_persistence.yml', '/content/sigma-master/rules/windows/registry_event/sysmon_removal_com_hijacking_registry_key.yml', '/content/sigma-master/rules/windows/registry_event/sysmon_cobaltstrike_service_installs.yml', '/content/sigma-master/rules/windows/registry_event/sysmon_disabled_pua_protection_on_microsoft_defender.yml', '/content/sigma-master/rules/windows/registry_event/sysmon_win_reg_persistence_recycle_bin.yml', '/content/sigma-master/rules/windows/registry_event/sysmon_win_reg_persistence_recycle_bin.yml', '/content/sigma-master/rules/windows/registry_event/sysmon_narrator_feedback_persistance.yml', '/content/sigma-master/rules/windows/registry_event/sysmon_removal_amsi_registry_key.yml', '/content/sigma-master/rules/windows/registry_event/registry_event_defender_realtime_protection_disabled.yml', '/content/sigma-master/rules/windows/registry_event/registry_event_defender_realtime_protection_disabled.yml', '/content/sigma-master/rules/windows/registry_event/sysmon_disable_microsoft_office_security_features.yml', '/content/sigma-master/rules/windows/registry_event/registry_event_defender_disabled.yml', '/content/sigma-master/rules/windows/registry_event/sysmon_disabled_tamper_protection_on_microsoft_defender.yml', '/content/sigma-master/rules/windows/registry_event/sysmon_taskcache_entry.yml', '/content/sigma-master/rules/windows/registry_event/registry_event_mstsc_history_cleared.yml', '/content/sigma-master/rules/windows/registry_event/registry_event_mstsc_history_cleared.yml', '/content/sigma-master/rules/windows/edr/edr_command_execution_ ...

# %%
column = "product"

search_str = ""
instr_prepre = f"SELECT * FROM logsources WHERE {column} LIKE '%{search_str}%'"
print(exec_selection(conn, instr_prepre))
instr_pre = f"SELECT document FROM ({instr_prepre})"
all_docs = exec_selection(conn,instr_pre)

#print(all_docs)
table  = "selections"
column = "fieldName"
search_str = "event"
instr = f"SELECT {column} FROM {table} WHERE {column} LIKE '%{search_str}%' AND document IN ({instr_pre}) GROUP BY {column}"
print("---------------------")
print(instr)
res  = exec_selection(conn,instr)
print(">>> : ",res)
# Out:
# [(1, 'authentication', '', '', '/content/sigma-master/rules/generic/generic_brute_force.yml'), (2, 'application', 'sql', '', '/content/sigma-master/rules/application/app_sqlinjection_errors.yml'), (3, 'application', 'sql', '', '/content/sigma-master/rules/application/app_sqlinjection_errors.yml'), (4, 'application', 'django', '', '/content/sigma-master/rules/application/appframework_django_exceptions.yml'), (5, 'application', 'django', '', '/content/sigma-master/rules/application/appframework_django_exceptions.yml'), (6, 'application', 'python', '', '/content/sigma-master/rules/application/app_python_sql_exceptions.yml'), (7, 'application', 'python', '', '/content/sigma-master/rules/application/app_python_sql_exceptions.yml'), (8, 'application', 'spring', '', '/content/sigma-master/rules/application/appframework_spring_exceptions.yml'), (9, 'application', 'spring', '', '/content/sigma-master/rules/application/appframework_spring_exceptions.yml'), (10, 'application', 'ruby_on_rails', '', '/content/sigma-master/rules/application/appframework_ruby_on_rails_exceptions.yml'), (11, 'application', 'ruby_on_rails', '', '/content/sigma-master/rules/application/appframework_ruby_on_rails_exceptions.yml'), (12, '', 'windows', 'powershell', '/content/sigma-master/rules/apt/apt_silence_eda.yml'), (13, '', 'windows', 'powershell', '/content/sigma-master/rules/apt/apt_silence_eda.yml'), (14, 'process_creation', 'windows', '', '/content/sigma-master/rules/apt/apt_silence_downloader_v3.yml'), (15, 'process_creation', 'windows', '', '/content/sigma-master/rules/apt/apt_silence_downloader_v3.yml'), (16, 'webserver', '', '', '/content/sigma-master/rules/web/web_exchange_proxyshell_successful.yml'), (17, 'webserver', '', '', '/content/sigma-master/rules/web/xss_keywords.yml'), (18, 'webserver', 'zoho_manageengine', '', '/content/sigma-master/rules/web/web_cve_2021_40539_manageengine_adselfservice_exploit.yml'), (19, 'webserver', 'zoho_manageengine', '', '/content/sigma-master/rules/web/web_cve_2021_40539_manageengine_adselfservice_exploit.yml'), (20, 'webserver', 'zoho_manageengine', '', '/content/sigma-master/rules/web/web_cve_2021_40539_manageengine_adselfservice_exploit.yml'), (21, '', 'apache', '', '/content/sigma-master/rules/web/web_nginx_core_dump.yml'), (22, 'webserver', '', '', '/content/sigma-master/rules/web/web_multiple_suspicious_resp_codes_single_source.yml'), (23, 'webserver', '', '', '/content/sigma-master/rules/web/win_webshell_regeorg.yml'), (24, 'webserver', '', '', '/content/sigma-master/rules/web/web_citrix_cve_2020_8193_8195_exploit.yml'), (25, '', 'apache', '', '/content/sigma-master/rules/web/web_apache_segfault.yml'), (26, 'webserver', '', '', '/content/sigma-master/rules/web/web_cve_2021_33766_msexchange_proxytoken.yml'), (27, 'webserver', '', '', '/content/sigma-master/rules/web/sql_injection_keywords.yml'), (28, 'webserver', '', '', '/content/sigma-master/rules/web/web_solarwinds_supernova_webshell.yml'), (29, 'webserver', '', '', '/content/sigma-master/rules/web/web_cve_2020_0688_msexchange.yml'), (30, 'webserver', '', '', '/content/sigma-master/rules/web/web_cve_2021_21978_vmware_view_planner_exploit.yml'), (31, 'webserver', '', '', '/content/sigma-master/rules/web/web_cve_2021_40539_adselfservice.yml'), (32, 'webserver', 'windows', '', '/content/sigma-master/rules/web/web_cve_2021_26858_iis_rce.yml'), (33, 'webserver', 'windows', '', '/content/sigma-master/rules/web/web_cve_2021_26858_iis_rce.yml'), (34, 'webserver', 'windows', '', '/content/sigma-master/rules/web/web_cve_2021_26858_iis_rce.yml'), (35, 'webserver', '', '', '/content/sigma-master/rules/web/web_cve_2010_5278_exploitation_attempt.yml'), (36, 'webserver', '', '', '/content/sigma-master/rules/web/web_unc2546_dewmode_php_webshell.yml'), (37, 'webserver', '', '', '/content/sigma-master/rules/web/web_cve_2019_3398_confluence.yml'), (38, 'webserver', '', '', '/content/sigma-master/rules/web/web_solarwinds_cve_2020_10148.yml'), (39, 'webserver', '', '', '/cont ...
# ---------------------
# SELECT fieldName FROM selections WHERE fieldName LIKE '%event%' AND document IN (SELECT document FROM (SELECT * FROM logsources WHERE product LIKE '%%')) GROUP BY fieldName
# >>> :  [('EventID',), ('EventLog',), ('EventType',), ('event.category',), ('eventName',), ('eventName|startswith',), ('eventService',), ('eventSource',), ('eventType',), ('event_type_id',), ('eventtype',)]

# %% [markdown]
# ## Heroku

# %%
# %cd /content/
# !python -m install virtualenv
# Out:
# /content
# /usr/bin/python3: No module named install

# %%
# !pip3 install virtualenv
# !virtualenv env
# Out:
# Collecting virtualenv
#   Downloading virtualenv-20.10.0-py2.py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 8.9 MB/s
# Requirement already satisfied: six<2,>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from virtualenv) (1.15.0)
# Collecting platformdirs<3,>=2
#   Downloading platformdirs-2.4.0-py3-none-any.whl (14 kB)
# Collecting backports.entry-points-selectable>=1.0.4
#   Downloading backports.entry_points_selectable-1.1.1-py2.py3-none-any.whl (6.2 kB)
# Collecting distlib<1,>=0.3.1
#   Downloading distlib-0.3.3-py2.py3-none-any.whl (496 kB)
#      |████████████████████████████████| 496 kB 74.5 MB/s
# Requirement already satisfied: filelock<4,>=3.2 in /usr/local/lib/python3.7/dist-packages (from virtualenv) (3.4.0)
# Requirement already satisfied: importlib-metadata>=0.12 in /usr/local/lib/python3.7/dist-packages (from virtualenv) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->virtualenv) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->virtualenv) (3.10.0.2)
# Installing collected packages: platformdirs, distlib, backports.entry-points-selectable, virtualenv
# Successfully installed backports.entry-points-selectable-1.1.1 distlib-0.3.3 platformdirs-2.4.0 virtualenv-20.10.0
# created virtual environment CPython3.7.12.final.0-64 in 804ms
#   creator CPython3Posix(dest=/content/env, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==21.3.1, setuptools==58.3.0, wheel==0.37.0
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !source /content/env/bin/activate
# !/content/env/bin/pip3 install flask gunicorn
# !/content/env/bin/pip3 freeze > requirements.txt
# Out:
# Requirement already satisfied: flask in ./env/lib/python3.7/site-packages (2.0.2)
# Requirement already satisfied: gunicorn in ./env/lib/python3.7/site-packages (20.1.0)
# Requirement already satisfied: Jinja2>=3.0 in ./env/lib/python3.7/site-packages (from flask) (3.0.3)
# Requirement already satisfied: itsdangerous>=2.0 in ./env/lib/python3.7/site-packages (from flask) (2.0.1)
# Requirement already satisfied: Werkzeug>=2.0 in ./env/lib/python3.7/site-packages (from flask) (2.0.2)
# Requirement already satisfied: click>=7.1.2 in ./env/lib/python3.7/site-packages (from flask) (8.0.3)
# Requirement already satisfied: setuptools>=3.0 in ./env/lib/python3.7/site-packages (from gunicorn) (58.3.0)
# Requirement already satisfied: importlib-metadata in ./env/lib/python3.7/site-packages (from click>=7.1.2->flask) (4.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in ./env/lib/python3.7/site-packages (from Jinja2>=3.0->flask) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in ./env/lib/python3.7/site-packages (from importlib-metadata->click>=7.1.2->flask) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in ./env/lib/python3.7/site-packages (from importlib-metadata->click>=7.1.2->flask) (4.0.0)

# %%
# !snap install --classic heroku
# Out:
# /bin/bash: snap: command not found

# %% [markdown]
# ## Flask

# %% [markdown]
# ### Installation Flask

# %%
# !pip install flask-ngrok
# Out:
# Collecting flask-ngrok
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.7/dist-packages (from flask-ngrok) (1.1.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from flask-ngrok) (2.23.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (2.11.3)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (1.1.0)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (7.1.2)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=0.8->flask-ngrok) (2.0.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (1.24.3)
# Installing collected packages: flask-ngrok
# Successfully installed flask-ngrok-0.0.25

# %%
all_yml = read_recursively()
logsources, selections  = get_all(all_yml)
print(logsources[0], selections[0])
conn = create_db()
add_data(conn, logsources, selections)
# Out:
# {'category': 'authentication', 'product': '', 'service': '', 'document': '/content/sigma-master/rules/generic/generic_brute_force.yml'} {'fieldName': 'action', 'value': 'failure', 'document': '/content/sigma-master/rules/generic/generic_brute_force.yml'}

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-336c6fbbfe10> in <module>()
# ----> 1 rch
#
# NameError: name 'rch' is not defined

# %%
from flask import Flask, render_template, jsonify, request
from flask_ngrok import run_with_ngrok
from sigma_module import *
app = Flask(__name__)
run_with_ngrok(app)   

@app.route("/")
def home():
  
  print("Launched !")
  return render_template('index.html')
@app.route("/search", methods=['GET'])
def search():
  with sqlite3.connect("pythonsqlite.db") as conn:
    terms = search_docs_by_term_in_column(conn, request.args.get("source"),request.args.get("column"), request.args.get("question"))
  response = jsonify(terms)
  response.headers.add('Access-Control-Allow-Origin', '*')
  return response
@app.route("/getDoc")
def getDoc():
  doc = request.args.get("doc")
  if os.path.isfile(doc):
    print("getDoc : Trouvé !")
  else :
    print("getDoc : Not found !")
  with open(doc, "r") as f:
    res = f.read()
  response = jsonify(res)
  response.headers.add('Access-Control-Allow-Origin', '*')
  return response
app.run()
