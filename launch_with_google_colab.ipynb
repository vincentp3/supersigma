# %% [markdown]
# <a href="https://colab.research.google.com/github/vincentp3/supersigma/blob/master/launch_with_google_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://github.com/vincentp3/supersigma/archive/refs/heads/master.zip
# !unzip master.zip
# %cd /content/supersigma-master
# !pip3 install -r requirements.txt
# !python3 wsgi.py
# Out:
# --2021-11-26 08:43:02--  https://github.com/vincentp3/supersigma/archive/refs/heads/master.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/vincentp3/supersigma/zip/refs/heads/master [following]
# --2021-11-26 08:43:02--  https://codeload.github.com/vincentp3/supersigma/zip/refs/heads/master
# Resolving codeload.github.com (codeload.github.com)... 140.82.112.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.112.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [  <=>               ]   4.94M  16.7MB/s    in 0.3s
#
# 2021-11-26 08:43:03 (16.7 MB/s) - ‘master.zip’ saved [5178557]
#
# Archive:  master.zip
# 2ff76c76b6c2d365a651e5d0573e1e4b5b41d8f7
#    creating: supersigma-master/
# ...
